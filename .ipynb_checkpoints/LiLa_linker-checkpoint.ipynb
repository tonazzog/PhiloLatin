# %%
from spacy_conll import init_parser
from spacy_conll.parser import ConllParser
from spacy.morphology import Morphology
import pandas as pd
import json

# %%
import requests

def process_lila_text(text):
    url = 'https://lila-erc.eu/LiLaTextLinker/processText'
    headers = {
        'Content-Type': 'application/json'
    }
    payload = {
        'text': text
    }
    
    response = requests.post(url, json=payload, headers=headers)
    
    if response.ok:
        return response.json()  # or response.text if you prefer raw output
    else:
        raise Exception(f"Request failed with status code {response.status_code}: {response.text}")

# %%
df_latin = pd.read_csv('./Latin-Philosophical-Expressions.csv', encoding = 'utf-8')

# %%
df_latin.head()
# Out:
#                        id                             latin_expression  \
# 0   a_dicto_secundum_quid  a dicto secundum quid ad dictum simpliciter
# 1  a_dicto_simpliciter_ad  a dicto simpliciter ad dictum secundum quid
# 2              a_fortiori                                   a fortiori
# 3       a_necesse_ad_esse         a necesse ad esse valet consequentia
# 4            a_posteriori                                 a posteriori
#
#                            expression_url        branch  \
# 0  https://www.wikidata.org/wiki/Q2456273         logic
# 1  https://www.wikidata.org/wiki/Q4660909         logic
# 2  https://www.wikidata.org/wiki/Q1753631         logic
# 3                                     NaN         logic
# 4   https://www.wikidata.org/wiki/Q300637  epistemology
#
#                             branch_url  \
# 0  https://www.wikidata.org/wiki/Q8078
# 1  https://www.wikidata.org/wiki/Q8078
# 2  https://www.wikidata.org/wiki/Q8078
# 3  https://www.wikidata.org/wiki/Q8078
# 4  https://www.wikidata.org/wiki/Q9471
#
#                                              concept  \
# 0  The phrase 'a dicto secundum quid ad dictum si...
# 1  The Latin phrase 'a dicto simpliciter ad dictu...
# 2  The Latin phrase 'a fortiori' translates to 'f...
# 3  The Latin phrase 'a necesse ad esse valet cons...
# 4  The term 'a posteriori' is a Latin phrase mean...
#
#                                      translation_eng  \
# 0  from a statement qualified to a statement unqu...
# 1  from the saying absolutely to the saying with ...
# 2                                         a fortiori
# 3    From necessity to being, the consequence holds.
# 4                                    from the latter
#
#                                            sense_eng  \
# 0  This phrase refers to the logical fallacy of m...
# 1  This phrase refers to the logical fallacy of m...
# 2  A Latin term meaning 'with stronger reason', u...
# 3  This phrase suggests that if something is nece...
# 4  A method of reasoning or knowledge that is der...
#
#                                      translation_ita  \
# 0  dal detto secondo il quale al detto semplicemente
# 1     da un detto semplice a un detto secondo quanto
# 2                                  a maggior ragione
# 3         Da necessario a essere vale la conseguenza
# 4                                       a posteriori
#
#                                            sense_ita  \
# 0  Questo concetto filosofico si riferisce alla d...
# 1  Questo concetto filosofico indica la distinzio...
# 2  Il termine 'a fortiori' indica un ragionamento...
# 3  Questo concetto filosofico indica che se qualc...
# 4  Il termine 'a posteriori' si riferisce a una c...
#
#                                            sense_lat
# 0  A dicto secundum quid ad dictum simpliciter si...
# 1  A dicto simpliciter ad dictum secundum quid si...
# 2  Argumentum a fortiori: si aliquid verum est in...
# 3  Consequentia ad necessarium esse valet, si res...
# 4  Cognitio ex experientia; veritas quae ex obser...

# %% [markdown]
# ### Link to LiLa Lemma

# %%
results = {}
for _, row in df_latin.iterrows():
    print(expression)
    expression = row['latin_expression'].replace(",","")
    result = process_lila_text(expression)
    results[row['id']] = result

with open("lila_linking.json", "w") as f:
    json.dump(results, f, indent=4)
# Out:
# vox populi vox dei
# a dicto secundum quid ad dictum simpliciter
# a dicto simpliciter ad dictum secundum quid
# a fortiori
# a necesse ad esse valet consequentia
# a posteriori
# a priori
# ab esse ad posse valet consequentia
# ab ovo
# actus purus
# ad hoc
# ad hoc hypothesis
# ad infinitum
# amicus Plato sed magis amica veritas
# amor fati
# anima mundi
# argumentum ad baculum
# argumentum ad hominem
# argumentum ad populum
# ars gratia artis
# barbara
# bellum omnium contra omnes
# causa sine qua non
# causa sui
# ceteris paribus
# characteristica universalis
# cogito ergo sum
# conditio sine qua non
# consequentia mirabilis
# creatio ex nihilo
# credo quia absurdum est
# credo quia impossibile est
# credo ut intelligam
# cui bono?
# de dicto
# de facto
# de gustibus non disputandum
# de jure
# de re
# deus sive natura
# dictum de omni et nullo
# do ut des
# dubito ergo cogito ergo sum
# dum spiro spero
# ens causa sui
# ens rationis
# ens realissimum
# entia non sunt multiplicanda praeter necessitatem
# esse est percipi
# ex falso quodlibet
# ex nihilo nihil fit
# ex post facto
# ex vi terminorum
# felix qui potuit rerum cognoscere causas
# fiat justitia ruat caelum
# fides quaerens intellectum
# fundamentum divisionis
# genius loci
# homo oeconomicus
# homo faber
# homo homini lupus
# hypotheses non fingo
# id quod nihil maius cogitari potest
# ignoratio elenchi
# in absentia
# in actu
# in cauda venenum
# in esse
# in medias res
# in nuce
# in potentia
# in propria persona
# intellectus agens
# intellectus possibilis
# inter finitum et infinitum non est proportio
# inventio medii
# ipse dixit
# ipsissima verba
# ipso facto
# lex parsimoniae
# lex talionis
# locus classicus
# materia prima
# memento mori
# mens rea
# modus ponens
# modus tollens
# modus vivendi
# mundus intelligibilis
# mundus sensibilis
# mutatis mutandis
# natura naturans
# natura naturata
# nihil in intellectu nisi prius in sensu
# nihil obstat
# nomen est omen
# non sequitur
# nosce te ipsum
# obiter dictum
# obscurum per obscurius
# per accidens
# per genus et differentiam
# per se
# per se notum
# persona non grata
# petitio principii
# phenomena bene fundata
# philosophia perennis
# pons asinorum
# post hoc ergo propter hoc
# praedicabilia
# prima causa
# prima facie
# primum mobile
# primum non nocere
# principium individuationis
# pro bono
# proprio motu
# quid pro quo
# quod erat demonstrandum
# quod gratis asseritur gratis negatur
# quot homines tot sententiae
# ratio cognoscendi
# ratio essendi
# reductio ad absurdum
# res cogitans
# res extensa
# res publica
# sacrificium intellectus
# salva veritate
# scientia libera
# scientia media
# scientia naturalis
# sensus communis
# sensus divinitatis
# simplicius sigillum veri
# sine qua non
# solo numero
# solus ipse
# solvitur ambulando
# status quo
# stipendium peccati mors est
# sub specie aeternitatis
# sui generis
# summum bonum
# tabula rasa
# terminus ad quem
# tertium non datur
# tertium quid
# vade mecum
# veritas vos liberabit
# via negativa
# vice versa
# vis inertiae

# %% [markdown]
# ### Links to correct manually

# %%
with open("./lila_linking.json", "r") as f:
    text = f.read()
results = json.loads(text)

# %% [markdown]
# ### Missing links

# %%
for id_, result in results.items():
    if result['stats']['missing'] > 0:
        for sentence in result['sentences']:
            for token in sentence:
                if len(token['linking']) == 0:
                    print(token)
# Out:
# {'token': 'necesse', 'lemma': 'necesse', 'upos': 'ADJ', 'spaceAfter': ' ', 'linking': []}
# {'token': 'hypothesis', 'lemma': 'haypothesis', 'upos': 'NOUN', 'spaceAfter': '', 'linking': []}
# {'token': 'characteristica', 'lemma': 'characteristica', 'upos': 'NOUN', 'spaceAfter': ' ', 'linking': []}
# {'token': 'spiro', 'lemma': 'spiro', 'upos': 'NOUN', 'spaceAfter': ' ', 'linking': []}
# {'token': 'realissimum', 'lemma': 'realissimus', 'upos': 'NOUN', 'spaceAfter': '', 'linking': []}
# {'token': 'oeconomicus', 'lemma': 'oeconomicus', 'upos': 'ADJ', 'spaceAfter': '', 'linking': []}
# {'token': 'hypotheses', 'lemma': 'haypothesis', 'upos': 'NOUN', 'spaceAfter': ' ', 'linking': []}
# {'token': 'elenchi', 'lemma': 'elencho', 'upos': 'VERB', 'spaceAfter': '', 'linking': []}
# {'token': 'naturans', 'lemma': 'naturor', 'upos': 'VERB', 'spaceAfter': '', 'linking': []}
# {'token': 'naturata', 'lemma': 'natuerno', 'upos': 'VERB', 'spaceAfter': '', 'linking': []}
# {'token': 'obscurius', 'lemma': 'obscur', 'upos': 'ADJ', 'spaceAfter': '', 'linking': []}
# {'token': 'phenomena', 'lemma': 'phenomena', 'upos': 'NOUN', 'spaceAfter': ' ', 'linking': []}

# %% [markdown]
# ### Ambiguous links

# %%
for id_, result in results.items():
    if result['stats']['ambiguous'] > 0:
        for sentence in result['sentences']:
            for token in sentence:
                if len(token['linking']) > 1:
                    print(token)
# Out:
# {'token': 'mundi', 'lemma': 'mundus', 'upos': 'NOUN', 'spaceAfter': '', 'linking': ['lilaLemma:112290', 'lilaLemma:113022', 'lilaLemma:113024']}
# {'token': 'populum', 'lemma': 'populus', 'upos': 'NOUN', 'spaceAfter': '', 'linking': ['lilaLemma:118463', 'lilaLemma:118501']}
# {'token': 'cogito', 'lemma': 'cogito', 'upos': 'VERB', 'spaceAfter': ' ', 'linking': ['lilaLemma:94718', 'lilaLemma:97288']}
# {'token': 'ergo', 'lemma': 'ergo', 'upos': 'ADP', 'spaceAfter': ' ', 'linking': ['lilaLemma:101404', 'lilaLemma:101414']}
# {'token': 'dictum', 'lemma': 'dico', 'upos': 'VERB', 'spaceAfter': ' ', 'linking': ['lilaLemma:99301', 'lilaLemma:99302']}
# {'token': 'ergo', 'lemma': 'ergo', 'upos': 'ADP', 'spaceAfter': ' ', 'linking': ['lilaLemma:101404', 'lilaLemma:101414']}
# {'token': 'cogito', 'lemma': 'cogito', 'upos': 'VERB', 'spaceAfter': ' ', 'linking': ['lilaLemma:94718', 'lilaLemma:97288']}
# {'token': 'ergo', 'lemma': 'ergo', 'upos': 'ADP', 'spaceAfter': ' ', 'linking': ['lilaLemma:101404', 'lilaLemma:101414']}
# {'token': 'vi', 'lemma': 'uis', 'upos': 'NOUN', 'spaceAfter': ' ', 'linking': ['lilaLemma:130360', 'lilaLemma:156435']}
# {'token': 'caelum', 'lemma': 'caelum', 'upos': 'NOUN', 'spaceAfter': '', 'linking': ['lilaLemma:92231', 'lilaLemma:97622']}
# {'token': 'fides', 'lemma': 'fides', 'upos': 'NOUN', 'spaceAfter': ' ', 'linking': ['lilaLemma:103260', 'lilaLemma:103261']}
# {'token': 'cogitari', 'lemma': 'cogito', 'upos': 'VERB', 'spaceAfter': ' ', 'linking': ['lilaLemma:94718', 'lilaLemma:97288']}
# {'token': 'dixit', 'lemma': 'dico', 'upos': 'VERB', 'spaceAfter': '', 'linking': ['lilaLemma:99301', 'lilaLemma:99302']}
# {'token': 'mundus', 'lemma': 'mundus', 'upos': 'NOUN', 'spaceAfter': ' ', 'linking': ['lilaLemma:112290', 'lilaLemma:113022', 'lilaLemma:113024']}
# {'token': 'mundus', 'lemma': 'mundus', 'upos': 'NOUN', 'spaceAfter': ' ', 'linking': ['lilaLemma:112290', 'lilaLemma:113022', 'lilaLemma:113024']}
# {'token': 'omen', 'lemma': 'omen', 'upos': 'NOUN', 'spaceAfter': '', 'linking': ['lilaLemma:114892', 'lilaLemma:114921']}
# {'token': 'dictum', 'lemma': 'dico', 'upos': 'VERB', 'spaceAfter': '', 'linking': ['lilaLemma:99301', 'lilaLemma:99302']}
# {'token': 'genus', 'lemma': 'genus', 'upos': 'NOUN', 'spaceAfter': ' ', 'linking': ['lilaLemma:104498', 'lilaLemma:104499', 'lilaLemma:104504']}
# {'token': 'bene', 'lemma': 'bene', 'upos': 'ADV', 'spaceAfter': ' ', 'linking': ['lilaLemma:91473', 'lilaIpoLemma:112681']}
# {'token': 'fundata', 'lemma': 'fundo', 'upos': 'VERB', 'spaceAfter': '', 'linking': ['lilaLemma:104012', 'lilaLemma:104013']}
# {'token': 'ergo', 'lemma': 'ergo', 'upos': 'ADP', 'spaceAfter': ' ', 'linking': ['lilaLemma:101404', 'lilaLemma:101414']}
# {'token': 'asseritur', 'lemma': 'assero', 'upos': 'VERB', 'spaceAfter': ' ', 'linking': ['lilaLemma:90320', 'lilaLemma:90321']}
# {'token': 'negatur', 'lemma': 'nego', 'upos': 'VERB', 'spaceAfter': '', 'linking': ['lilaLemma:67302', 'lilaLemma:113553']}
# {'token': 'cogitans', 'lemma': 'cogito', 'upos': 'VERB', 'spaceAfter': '', 'linking': ['lilaLemma:94718', 'lilaLemma:97288']}
# {'token': 'status', 'lemma': 'status', 'upos': 'NOUN', 'spaceAfter': ' ', 'linking': ['lilaLemma:82146', 'lilaLemma:82147', 'lilaLemma:127471']}
# {'token': 'generis', 'lemma': 'genus', 'upos': 'NOUN', 'spaceAfter': '', 'linking': ['lilaLemma:104498', 'lilaLemma:104499', 'lilaLemma:104504']}
# {'token': 'vade', 'lemma': 'uado', 'upos': 'VERB', 'spaceAfter': ' ', 'linking': ['lilaLemma:129476', 'lilaLemma:129481']}
# {'token': 'vis', 'lemma': 'uolo', 'upos': 'VERB', 'spaceAfter': ' ', 'linking': ['lilaLemma:130745', 'lilaLemma:130746']}
# {'token': 'populi', 'lemma': 'populus', 'upos': 'NOUN', 'spaceAfter': ' ', 'linking': ['lilaLemma:118463', 'lilaLemma:118501']}
