# %%
from rdflib import Graph, Literal, RDF, URIRef, Namespace
import pandas as pd
import requests
import json
import pyconll

# %%
def generate_expression_id(expression):
    expression = expression.replace(",", "").replace("?", "")
    w = expression.split(" ")
    return "_".join(w[ : 4])

# %% [markdown]
# ### Latin philosophical expression

# %%
df_latin = pd.read_csv('./Latin-Philosophical-Expressions.csv', encoding = 'utf-8')

# %%
df_latin = df_latin.fillna('')

# %%
df_latin.head()
# Out:
#                        id                             latin_expression  \
# 0   a_dicto_secundum_quid  a dicto secundum quid ad dictum simpliciter
# 1  a_dicto_simpliciter_ad  a dicto simpliciter ad dictum secundum quid
# 2              a_fortiori                                   a fortiori
# 3       a_necesse_ad_esse         a necesse ad esse valet consequentia
# 4            a_posteriori                                 a posteriori
#
#                            expression_url        branch  \
# 0  https://www.wikidata.org/wiki/Q2456273         logic
# 1  https://www.wikidata.org/wiki/Q4660909         logic
# 2  https://www.wikidata.org/wiki/Q1753631         logic
# 3                                                 logic
# 4   https://www.wikidata.org/wiki/Q300637  epistemology
#
#                             branch_url  \
# 0  https://www.wikidata.org/wiki/Q8078
# 1  https://www.wikidata.org/wiki/Q8078
# 2  https://www.wikidata.org/wiki/Q8078
# 3  https://www.wikidata.org/wiki/Q8078
# 4  https://www.wikidata.org/wiki/Q9471
#
#                                              concept  \
# 0  The phrase 'a dicto secundum quid ad dictum si...
# 1  The Latin phrase 'a dicto simpliciter ad dictu...
# 2  The Latin phrase 'a fortiori' translates to 'f...
# 3  The Latin phrase 'a necesse ad esse valet cons...
# 4  The term 'a posteriori' is a Latin phrase mean...
#
#                                      translation_eng  \
# 0  from a statement qualified to a statement unqu...
# 1  from the saying absolutely to the saying with ...
# 2                                         a fortiori
# 3    From necessity to being, the consequence holds.
# 4                                    from the latter
#
#                                            sense_eng  \
# 0  This phrase refers to the logical fallacy of m...
# 1  This phrase refers to the logical fallacy of m...
# 2  A Latin term meaning 'with stronger reason', u...
# 3  This phrase suggests that if something is nece...
# 4  A method of reasoning or knowledge that is der...
#
#                                      translation_ita  \
# 0  dal detto secondo il quale al detto semplicemente
# 1     da un detto semplice a un detto secondo quanto
# 2                                  a maggior ragione
# 3         Da necessario a essere vale la conseguenza
# 4                                       a posteriori
#
#                                            sense_ita  \
# 0  Questo concetto filosofico si riferisce alla d...
# 1  Questo concetto filosofico indica la distinzio...
# 2  Il termine 'a fortiori' indica un ragionamento...
# 3  Questo concetto filosofico indica che se qualc...
# 4  Il termine 'a posteriori' si riferisce a una c...
#
#                                            sense_lat
# 0  A dicto secundum quid ad dictum simpliciter si...
# 1  A dicto simpliciter ad dictum secundum quid si...
# 2  Argumentum a fortiori: si aliquid verum est in...
# 3  Consequentia ad necessarium esse valet, si res...
# 4  Cognitio ex experientia; veritas quae ex obser...

# %% [markdown]
# ### Different interpretations (senses)

# %%
df_senses = pd.read_csv('./Latin-Expressions-Senses.csv', encoding = 'utf-8')

# %%
df_senses = df_senses.fillna('')

# %%
df_senses.head()
# Out:
#                                     expression associated_with  \
# 0  a dicto secundum quid ad dictum simpliciter       Aristotle
# 1  a dicto secundum quid ad dictum simpliciter  Thomas Aquinas
# 2  a dicto secundum quid ad dictum simpliciter   Immanuel Kant
# 3  a dicto secundum quid ad dictum simpliciter         Leibniz
# 4  a dicto simpliciter ad dictum secundum quid       Aristotle
#
#                                                sense                      id  \
# 0  Aristotle uses this expression to differentiat...   a_dicto_secundum_quid
# 1  Aquinas interprets this phrase in the context ...   a_dicto_secundum_quid
# 2  Kant might interpret this expression in relati...   a_dicto_secundum_quid
# 3  Leibniz could view this distinction as a refle...   a_dicto_secundum_quid
# 4  Aristotle uses this expression to differentiat...  a_dicto_simpliciter_ad
#
#                        associated_with_url
# 0  https://www.wikidata.org/wiki/Q84473023
# 1      https://www.wikidata.org/wiki/Q9438
# 2      https://www.wikidata.org/wiki/Q9312
# 3      https://www.wikidata.org/wiki/Q9047
# 4  https://www.wikidata.org/wiki/Q84473023

# %% [markdown]
# ## Linking to LiLa lemmas

# %%
with open("./lila_linking_final.json", "r") as f:
    text = f.read()
lila_linking = json.loads(text)

# %% [markdown]
# ## Linked concepts

# %%
linked_concepts = [
    ["a dicto secundum quid ad dictum simpliciter","a dicto simpliciter ad dictum secundum quid"],
    ["a priori","a posteriori","a fortiori"],
    ["argumentum ad baculum","argumentum ad hominem","argumentum ad populum"],
    ["bellum omnium contra omnes","homo homini lupus"],
    ["modus ponens","modus tollens"],
    ["de dicto","de facto","de jure","de re"],
    ["in actu","in esse","in potentia"],
    ["mundus intelligibilis","mundus sensibilis"],
    ["per accidens","per se"],
    ["res cogitans", "res extensa"],
    ["tabula rasa","nihil in intellectu nisi prius in sensu"]
]

# %%
linked_concepts_list = [generate_expression_id(concept)  for concepts in linked_concepts for concept in concepts]

# %%
linked_concepts_dict = {c : {'uri':'', 'links' : []} for c in set(linked_concepts_list)}

# %%
for concepts in linked_concepts:
    for concept in concepts:
        concept_id = generate_expression_id(concept)       
        for linked_concept in concepts:
            if linked_concept != concept:
                 linked_concepts_dict[concept_id]['links'].append(generate_expression_id(linked_concept))

# %%
linked_concepts_dict
# Out:
# {'res_cogitans': {'uri': '', 'links': ['res_extensa']},
#  'mundus_sensibilis': {'uri': '', 'links': ['mundus_intelligibilis']},
#  'de_dicto': {'uri': '', 'links': ['de_facto', 'de_jure', 'de_re']},
#  'argumentum_ad_baculum': {'uri': '',
#   'links': ['argumentum_ad_hominem', 'argumentum_ad_populum']},
#  'in_actu': {'uri': '', 'links': ['in_esse', 'in_potentia']},
#  'de_re': {'uri': '', 'links': ['de_dicto', 'de_facto', 'de_jure']},
#  'homo_homini_lupus': {'uri': '', 'links': ['bellum_omnium_contra_omnes']},
#  'modus_tollens': {'uri': '', 'links': ['modus_ponens']},
#  'res_extensa': {'uri': '', 'links': ['res_cogitans']},
#  'modus_ponens': {'uri': '', 'links': ['modus_tollens']},
#  'a_posteriori': {'uri': '', 'links': ['a_priori', 'a_fortiori']},
#  'argumentum_ad_hominem': {'uri': '',
#   'links': ['argumentum_ad_baculum', 'argumentum_ad_populum']},
#  'nihil_in_intellectu_nisi': {'uri': '', 'links': ['tabula_rasa']},
#  'argumentum_ad_populum': {'uri': '',
#   'links': ['argumentum_ad_baculum', 'argumentum_ad_hominem']},
#  'de_facto': {'uri': '', 'links': ['de_dicto', 'de_jure', 'de_re']},
#  'per_accidens': {'uri': '', 'links': ['per_se']},
#  'mundus_intelligibilis': {'uri': '', 'links': ['mundus_sensibilis']},
#  'a_dicto_simpliciter_ad': {'uri': '', 'links': ['a_dicto_secundum_quid']},
#  'in_potentia': {'uri': '', 'links': ['in_actu', 'in_esse']},
#  'tabula_rasa': {'uri': '', 'links': ['nihil_in_intellectu_nisi']},
#  'a_dicto_secundum_quid': {'uri': '', 'links': ['a_dicto_simpliciter_ad']},
#  'de_jure': {'uri': '', 'links': ['de_dicto', 'de_facto', 'de_re']},
#  'in_esse': {'uri': '', 'links': ['in_actu', 'in_potentia']},
#  'per_se': {'uri': '', 'links': ['per_accidens']},
#  'bellum_omnium_contra_omnes': {'uri': '', 'links': ['homo_homini_lupus']},
#  'a_fortiori': {'uri': '', 'links': ['a_priori', 'a_posteriori']},
#  'a_priori': {'uri': '', 'links': ['a_posteriori', 'a_fortiori']}}

# %% [markdown]
# ## UD Pipe

# %%
def call_udpipe_and_parse(text, model='latin-evalatin24-240520'):
    url = 'https://lindat.mff.cuni.cz/services/udpipe/api/process'
    params = {
        'tokenizer': '',
        'tagger': '',
        'parser': '',
        'data': text,
        'model': model
    }

    response = requests.post(url, data=params)
    
    if response.status_code == 200:
        result = response.json()
        conllu_result = result.get('result')
        if conllu_result:
            # Parse CoNLL-U with pyconll
            conll_data = pyconll.load_from_string(conllu_result)
            return conll_data
        else:
            print("No CoNLL-U output found. Error:", result.get('error', 'Unknown error'))
            return None
    else:
        print(f"HTTP Error {response.status_code}: {response.text}")
        return None

# %% [markdown]
# ## Create triples

# %%
def create_uri(namespace, resource_type, identifier, language=None):
   
    identifier = str(identifier).lower().replace(' ', '-').replace('_', '-')
    
    if language:
        # Language-specific resources
        return namespace[f"{resource_type}/{language}/{identifier}"]
    else:
        # Language-neutral resources
        return namespace[f"{resource_type}/{identifier}"]

# %%
from rdflib import Graph, URIRef, Literal, Namespace
from rdflib.namespace import RDF, RDFS, OWL, DC, FOAF, SKOS, DCTERMS

# Define namespaces
ONTOLEX = Namespace("http://www.w3.org/ns/lemon/ontolex#")
LEXINFO = Namespace("http://www.lexinfo.net/ontology/2.0/lexinfo#")
LIME = Namespace("http://www.w3.org/ns/lemon/lime#")
VARTRANS = Namespace("http://www.w3.org/ns/lemon/vartrans#")
PROV = Namespace("http://www.w3.org/ns/prov#")
WD = Namespace("http://www.wikidata.org/entity/")
DCT = Namespace("http://purl.org/dc/terms/")
OA = Namespace("http://www.w3.org/ns/oa#")

POWLA = Namespace("http://purl.org/powla/powla.owl#")
NIF = Namespace("http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#")
LILA = Namespace("http://lila-erc.eu/ontologies/lila/")

# My namespace
LP = Namespace("http://latinphilosophy.org/")

# %%
g = Graph()
    
# Binding
g.bind("ontolex", ONTOLEX)
g.bind("lexinfo", LEXINFO)
g.bind("lime", LIME)
g.bind("skos", SKOS)
g.bind("dcterms", DCTERMS)
g.bind("vartrans", VARTRANS)
g.bind("prov", PROV)
g.bind("dct", DCT)
g.bind("powla", POWLA)
g.bind("nif", NIF)
g.bind("foaf", FOAF)
g.bind("lila", LILA)
g.bind("oa", OA)

g.bind("lp", LP)

# Corpus
corpus_uri =LP["corpus"]
g.add((corpus_uri, RDF.type, POWLA.Corpus))
g.add((corpus_uri, RDFS.label, Literal('Philosophical Latin Expressions Corpus')))  
g.add((corpus_uri, DCT.creator, Literal('Giovanna Tonazzo')))  

# Document and citation layers
doc_uri = create_uri(LP, "layer", "document")
g.add((doc_uri, RDF.type, POWLA.DocumentLayer))
g.add((doc_uri, RDFS.label, Literal('Document Layer')))
g.add((doc_uri, POWLA.hasDocument, corpus_uri))

cit_uri = create_uri(LP, "layer", "expression")
g.add((cit_uri, RDF.type, POWLA.DocumentLayer))
g.add((cit_uri, RDFS.label, Literal('Expression Layer')))
g.add((cit_uri, POWLA.hasDocument, corpus_uri))

# Create annotation layers
ud_layer = create_uri(LP, "layer", "ud")
g.add((ud_layer, RDF.type, POWLA.Layer))
g.add((ud_layer, RDFS.label, Literal('UD Annotation Layer')))  
                                             
sem_layer = create_uri(LP, "layer", "semantics")
g.add((sem_layer, RDF.type, POWLA.Layer))
g.add((sem_layer, RDFS.label, Literal('Semantic Annotation Layer')))  
         
dep_layer = create_uri(LP, "layer", "dependency")
g.add((dep_layer, RDF.type, POWLA.Layer))
g.add((dep_layer, RDFS.label, Literal('Dependency Annotation Layer')))

g.add((corpus_uri, POWLA.hasLayer, ud_layer))
g.add((corpus_uri, POWLA.hasLayer, sem_layer))
g.add((corpus_uri, POWLA.hasLayer, dep_layer))

# Lexicon for Latin and English
lat_lex_uri = create_uri(LP, "lexicon", "la")
g.add((lat_lex_uri, RDF.type, LIME.lexicon))
g.add((lat_lex_uri, RDFS.label, Literal('Latin lexicon')))

eng_lex_uri = create_uri(LP, "lexicon", "en")
g.add((eng_lex_uri, RDF.type, LIME.lexicon))
g.add((eng_lex_uri, RDFS.label, Literal('English lexicon')))

# Create  triples for each expression
for index, row in df_latin.iterrows():
    
    expr_id = row['id']
    latin_expr = row['latin_expression']    
    branch = row['branch']
    branch_url = row['branch_url']
    expr_url = row['expression_url']        
    concept = row['concept']
    expr_trans_eng = row['translation_eng']
    expr_sense_eng = row['sense_eng']
    expr_sense_lat = row['sense_lat']

    print(latin_expr)
    #g.add((ONTOLEX.Form, RDFS.label, Literal('Form')))
    #g.add((ONTOLEX.LexicalEntry, RDFS.label, Literal('Lexical entry')))  
    #g.add((VARTRANS.Translation, RDFS.label, Literal('Translation')))
    #g.add((ONTOLEX.LexicalSense, RDFS.label, Literal('Lexical Sense')))
    #g.add((ONTOLEX.LexicalConcept, RDFS.label, Literal('Lexical Concept')))      

    # Concept
    concept_uri = create_uri(LP, "concept", index)
    g.add((concept_uri, RDF.type, SKOS.Concept))
    g.add((concept_uri, RDFS.label,  Literal(f'Concept of {latin_expr}', lang="en")))
    g.add((concept_uri, SKOS.definition, Literal(concept, lang="en"))) 
    sem_annot_uri = create_uri(LP, 'semantics', f'expr-{index}')
    g.add((sem_annot_uri, RDFS.label, Literal(f'Semantic annotation of {latin_expr}')))
    g.add((sem_annot_uri, RDF.type, POWLA.Node))
    g.add((sem_annot_uri, POWLA.hasLayer, sem_layer))
    g.add((sem_annot_uri, DC.subject, concept_uri))

    if linked_concepts_dict.get(expr_id):
        linked_concepts_dict[expr_id]['uri'] = concept_uri
    
    # Link to branch of philosophy
    branch_id = branch.lower().replace(" ", "-")
    branch_uri = create_uri(LP, "branch", branch_id)
    g.add((branch_uri, RDF.type, SKOS.Concept))
    g.add((branch_uri, SKOS.prefLabel, Literal(branch.capitalize(), lang="en")))
    g.add((concept_uri, SKOS.broader, branch_uri))   
    if branch_url:   
        g.add((branch_uri, RDFS.seeAlso, URIRef(branch_url)))
        
    # Link to Wikidata if available
    wiki_id = expr_url.split('/')[-1] if expr_url else None    
    if wiki_id:
        g.add((concept_uri, RDFS.seeAlso, WD[wiki_id]))
        
    # Lexical entry for Latin expression
    latin_entry_uri = create_uri(LP, "expression", index, "la")
    g.add((latin_entry_uri, RDF.type, ONTOLEX.LexicalEntry))
    g.add((latin_entry_uri, RDFS.label, Literal(latin_expr, lang="la")))    
    g.add((latin_entry_uri, RDF.type, POWLA.root))

    # Lexical form
    form_uri = create_uri(LP, "form", index, "la")
    g.add((form_uri, RDF.type, ONTOLEX.Form))
    g.add((latin_entry_uri, ONTOLEX.canonicalForm, form_uri))
    g.add((form_uri, ONTOLEX.writtenRep, Literal(latin_expr.capitalize(), lang="la")))

    # Lexical sense
    latin_sense_uri = create_uri(LP, "sense", index, "la")
    g.add((latin_sense_uri, RDF.type, ONTOLEX.LexicalSense))
    g.add((latin_entry_uri, ONTOLEX.sense, latin_sense_uri))    
    g.add((latin_sense_uri, RDFS.label, Literal(f'Latin sense of {latin_expr}', lang="la")))
    g.add((latin_sense_uri, SKOS.definition, Literal(expr_sense_lat, lang="la")))
    g.add((latin_sense_uri, ONTOLEX.reference, concept_uri))
    
    # Lexical entry for English translation
    english_entry_uri = create_uri(LP, "expression", index, "en")
    g.add((english_entry_uri, RDF.type, ONTOLEX.LexicalEntry))
    g.add((english_entry_uri, RDFS.label, Literal(expr_trans_eng, lang="en")))

    # Canonical form for English
    english_form_uri = create_uri(LP, "form", index, "en")
    g.add((english_form_uri, RDF.type, ONTOLEX.Form))
    g.add((english_entry_uri, ONTOLEX.canonicalForm, english_form_uri))
    g.add((english_form_uri, ONTOLEX.writtenRep, Literal(expr_trans_eng.capitalize(), lang="en")))

     # Sense for English translation
    english_sense_uri = create_uri(LP, "sense", index, "en")
    g.add((english_sense_uri, RDF.type, ONTOLEX.LexicalSense))
    g.add((english_entry_uri, ONTOLEX.sense, english_sense_uri))
    g.add((english_sense_uri, RDFS.label, Literal(f'English sense of {latin_expr}', lang="en")))
    g.add((english_sense_uri, SKOS.definition, Literal(expr_sense_eng, lang="en")))   
    g.add((english_sense_uri, ONTOLEX.reference, concept_uri ))
   
    
    #Translation relation
    trans_uri = create_uri(LP, "translation", index)
    g.add((trans_uri, RDF.type, VARTRANS.Translation))
    g.add((trans_uri, RDFS.label, Literal(f'Translation of {latin_expr}')))
    
    g.add((trans_uri, VARTRANS.source, latin_sense_uri))
    g.add((trans_uri, VARTRANS.target, english_sense_uri))
   
    # Different interpretations
    for sense_id , sense in df_senses[df_senses['id'] == expr_id].iterrows(): 
         # Lexical sense
        auth_id = sense['associated_with'].lower().replace(" ", "-")
        sense_uri = create_uri(LP, "sense", f'expr-{index}/{auth_id}', "en")
        g.add((sense_uri, RDF.type, ONTOLEX.concept))   
        g.add((sense_uri, RDFS.label, Literal(f'{sense['associated_with']} sense of {latin_expr}', lang="en")))
        g.add((sense_uri, SKOS.definition, Literal(sense['sense'], lang="en")))
        g.add((concept_uri, SKOS.narrower, sense_uri))

        auth_uri = create_uri(LP, "creator", auth_id)
        g.add((auth_uri,  RDFS.label, Literal(sense['associated_with'], lang="en")))
        g.add((auth_uri, FOAF.page, URIRef(sense['associated_with_url'])))
        g.add((sense_uri, DCT.creator, auth_uri))   
        g.add((concept_uri, DCT.creator, auth_uri))
        if sense['associated_with_url'] != '':   
            g.add((auth_uri, RDFS.seeAlso, URIRef(sense['associated_with_url'])))       
        
        if auth_id == 'plato':
            plato_uri = auth_uri
            
    # Add to citation layer
    g.add((latin_entry_uri, POWLA.hasLayer, cit_uri))

    # Add to lexicon layer
    g.add((latin_entry_uri, LIME.entry, lat_lex_uri))
    g.add((english_entry_uri, LIME.entry, eng_lex_uri))
    
    # Parse with UDPipe
    conll = call_udpipe_and_parse(latin_expr.replace(",","").replace("?",""))    
    if conll:                              
        for i, token in enumerate(conll[0]):
            
            # Terminal for the token
            token_id = i + 1
            powla_token_uri = create_uri(LP, 'token', f'expr-{index}/{token_id}') 
            token_form = token.form
                                                    
            g.add((powla_token_uri, RDF.type, POWLA.Terminal))
            g.add((powla_token_uri, RDFS.label, Literal(token_form, lang="la")))
            g.add((latin_entry_uri, POWLA.hasTerminal, powla_token_uri))
            g.add((powla_token_uri, POWLA.hasLayer, doc_uri))
    
            # First, next, last token relations
            if token_id == 1:
                g.add((latin_entry_uri, POWLA.first, powla_token_uri))        
            
            if token_id == len(conll[0]):
                g.add((latin_entry_uri, POWLA.last, powla_token_uri))
    
            if token_id > 1:
                prev_token_uri = create_uri(LP, 'token', f'expr_{index}/{token_id - 1}')
                g.add((powla_token_uri, POWLA.prev, prev_token_uri))
                g.add((prev_token_uri, POWLA.next, powla_token_uri))
    
            # Dependency relation
            if token.head:
                token_head = int(token.head)
                if token_head != 0:
                    dep_relation_uri = create_uri(LP, 'deprel', f'expr-{index}/{token_head}_{token_id}')
                    powla_head_uri = create_uri(LP, 'token', f'expr-{index}/{token_head}')      
                    g.add((dep_relation_uri, RDF.type, POWLA.Relation))
                    g.add((dep_relation_uri, RDFS.label, Literal(f'deprel: {token.deprel}')))
                    g.add((dep_relation_uri, POWLA.hasLayer, dep_layer))
                    g.add((dep_relation_uri, POWLA.hasSource, powla_head_uri))
                    g.add((dep_relation_uri, POWLA.hasTarget, powla_token_uri))
                    g.add((dep_relation_uri, POWLA.hasLabel, Literal(token.deprel)))    
            
            
            # UD annotations from conllu
            ud_node_uri = create_uri(LP, 'ud', f'expr-{index}/{token_id}')
            g.add((ud_node_uri, RDFS.label, Literal(f'UD annotation of {token_form}')))
            g.add((ud_node_uri, RDF.type, OA.annotation))
            g.add((ud_node_uri, POWLA.hasLayer, ud_layer))
            g.add((ud_node_uri, OA.hasTarget, powla_token_uri))
            #pos_node_uri = URIRef(f'https://universaldependencies.org/la/{token.upos}')
            pos_node_uri = create_uri(LP, 'pos', f'{token.upos}')
            g.add((pos_node_uri, RDFS.label, Literal(f'POS={token.upos}')))
            g.add((ud_node_uri, OA.hasBody, pos_node_uri))
    
            # Feats from conllu
            feats = dict(token.feats)
            for feat in feats:
                for f in feats[feat]:
                    #feat_node_uri = URIRef(f'https://universaldependencies.org/la/feat/{feat.capitalize()}#{f.capitalize()}')
                    feat_node_uri= create_uri(LP, 'feat', f'{feat.capitalize()}={f.capitalize()}')
                    g.add((feat_node_uri, RDFS.label, Literal(f'{feat.capitalize()}={f.capitalize()}')))
                    g.add((feat_node_uri, RDF.type, URIRef(f'https://universaldependencies.org/u/feat/{feat.capitalize()}#{f.capitalize()}')))
                    g.add((URIRef(f'https://universaldependencies.org/la/feat/{feat.capitalize()}#{f.capitalize()}'), RDFS.label, Literal(f'{feat.capitalize()}={f.capitalize()}')))
                    g.add((URIRef(f'https://universaldependencies.org/la/feat/{feat.capitalize()}#{f.capitalize()}'), DC.title, Literal(f'{feat.capitalize()}#{f.capitalize()}')))
                    g.add((ud_node_uri, OA.hasBody, feat_node_uri))
    
            if token.form == 'Plato':
                g.add((powla_token_uri, RDFS.seeAlso, plato_uri))
            
            # Link to LiLa lemma
            try :
                for sent in lila_linking[row['id']]['sentences']:
                    for lila_token in sent:
                        if lila_token['token'] == token_form:
                            if len(lila_token['linking']) > 0:
                                lila_link_info = lila_token['linking'][0].split(":")
                                lila_lemma_id = lila_link_info[1]                
                                lila_lemma_uri = URIRef(f'http://lila-erc.eu/data/id/lemma/{lila_lemma_id}')  
                                g.add((lila_lemma_uri, RDF.type, LILA.lemma))
                                g.add((lila_lemma_uri, RDFS.label, Literal(token.lemma)))
                                g.add((lila_lemma_uri, DC.title, Literal(token.lemma)))
                                g.add((powla_token_uri, LILA.hasLemma, lila_lemma_uri))
                            else:
                                print(latin_expr + " "+ " unmatched token in LiLa " + token.form + " " + lila_token['token'])
            except :
                print(latin_expr + " "+ " error linking " + token.form)
# Out:
# a dicto secundum quid ad dictum simpliciter
# a dicto simpliciter ad dictum secundum quid
# a fortiori
# a necesse ad esse valet consequentia
# a posteriori
# a priori
# ab esse ad posse valet consequentia
# ab ovo
# actus purus
# ad hoc
# ad hoc hypothesis
# ad infinitum
# amicus Plato sed magis amica veritas
# amor fati
# anima mundi
# argumentum ad baculum
# argumentum ad hominem
# argumentum ad populum
# ars gratia artis
# barbara
# bellum omnium contra omnes
# causa sine qua non
# causa sui
# ceteris paribus
# characteristica universalis
# cogito, ergo sum
# conditio sine qua non
# consequentia mirabilis
# creatio ex nihilo
# credo quia absurdum est
# credo quia impossibile est
# credo ut intelligam
# cui bono?
# de dicto
# de facto
# de gustibus non disputandum
# de jure
# de re
# deus sive natura
# dictum de omni et nullo
# do ut des
# dubito, ergo cogito, ergo sum
# dum spiro, spero
# ens causa sui
# ens rationis
# ens realissimum
# entia non sunt multiplicanda praeter necessitatem
# esse est percipi
# ex falso quodlibet
# ex nihilo nihil fit
# ex post facto
# ex vi terminorum
# felix qui potuit rerum cognoscere causas
# fiat justitia ruat caelum
# fides quaerens intellectum
# fundamentum divisionis
# genius loci
# homo oeconomicus
# homo faber
# homo homini lupus
# hypotheses non fingo
# id quod nihil maius cogitari potest
# ignoratio elenchi
# in absentia
# in actu
# in cauda venenum
# in esse
# in medias res
# in nuce
# in potentia
# in propria persona
# intellectus agens
# intellectus possibilis
# inter finitum et infinitum non est proportio
# inventio medii
# ipse dixit
# ipsissima verba
# ipso facto
# lex parsimoniae
# lex talionis
# locus classicus
# materia prima
# memento mori
# mens rea
# modus ponens
# modus tollens
# modus vivendi
# mundus intelligibilis
# mundus sensibilis
# mutatis mutandis
# natura naturans
# natura naturata
# nihil in intellectu nisi prius in sensu
# nihil obstat
# nomen est omen
# non sequitur
# nosce te ipsum
# obiter dictum
# obscurum per obscurius
# per accidens
# per genus et differentiam
# per se
# per se notum
# persona non grata
# petitio principii
# phenomena bene fundata
# philosophia perennis
# pons asinorum
# post hoc ergo propter hoc
# praedicabilia
# prima causa
# prima facie
# primum mobile
# primum non nocere
# principium individuationis
# pro bono
# proprio motu
# quid pro quo
# quod erat demonstrandum
# quod gratis asseritur, gratis negatur
# quot homines tot sententiae
# ratio cognoscendi
# ratio essendi
# reductio ad absurdum
# res cogitans
# res extensa
# res publica
# sacrificium intellectus
# salva veritate
# scientia libera
# scientia media
# scientia naturalis
# sensus communis
# sensus divinitatis
# simplicius sigillum veri
# sine qua non
# solo numero
# solus ipse
# solvitur ambulando
# status quo
# stipendium peccati mors est
# sub specie aeternitatis
# sui generis
# summum bonum
# tabula rasa
# terminus ad quem
# tertium non datur
# tertium quid
# vade mecum
# veritas vos liberabit
# via negativa
# vice versa
# vis inertiae
# vox populi, vox dei

# %%
# Add links between concepts
for key, value in linked_concepts_dict.items():
     concept_uri = value['uri']
     for link in value['links']:
         g.add((concept_uri, SKOS.related, linked_concepts_dict[link]['uri']))

# %%
print(g.serialize(format="turtle"))
# Out:
# @prefix dc: <http://purl.org/dc/elements/1.1/> .
# @prefix dct: <http://purl.org/dc/terms/> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix lila: <http://lila-erc.eu/ontologies/lila/> .
# @prefix lime: <http://www.w3.org/ns/lemon/lime#> .
# @prefix lp: <http://latinphilosophy.org/> .
# @prefix oa: <http://www.w3.org/ns/oa#> .
# @prefix ontolex: <http://www.w3.org/ns/lemon/ontolex#> .
# @prefix powla: <http://purl.org/powla/powla.owl#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix skos: <http://www.w3.org/2004/02/skos/core#> .
# @prefix vartrans: <http://www.w3.org/ns/lemon/vartrans#> .
#
# <http://latinphilosophy.org/deprel/expr-0/2-1> a powla:Relation ;
#     rdfs:label "deprel: case" ;
#     powla:hasLabel "case" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/dependency> ;
#     powla:hasSource <http://latinphilosophy.org/token/expr-0/2> ;
#     powla:hasTarget <http://latinphilosophy.org/token/expr-0/1> .
#
# <http://latinphilosophy.org/deprel/expr-0/2-4> a powla:Relation ;
#     rdfs:label "deprel: nmod" ;
#     powla:hasLabel "nmod" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/dependency> ;
#     powla:hasSource <http://latinphilosophy.org/token/expr-0/2> ;
#     powla:hasTarget <http://latinphilosophy.org/token/expr-0/4> .
#
# <http://latinphilosophy.org/deprel/expr-0/2-6> a powla:Relation ;
#     rdfs:label "deprel: obl" ;
#     powla:hasLabel "obl" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/dependency> ;
#     powla:hasSource <http://latinphilosophy.org/token/expr-0/2> ;
#     powla:hasTarget <http://latinphilosophy.org/token/expr-0/6> .
#
# <http://latinphilosophy.org/deprel/expr-0/4-3> a powla:Relation ;
#     rdfs:label "deprel: case" ;
#     powla:hasLabel "case" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/dependency> ;
#     powla:hasSource <http://latinphilosophy.org/token/expr-0/4> ;
#     powla:hasTarget <http://latinphilosophy.org/token/expr-0/3> .
#
# <http://latinphilosophy.org/deprel/expr-0/6-5> a powla:Relation ;
#     rdfs:label "deprel: case" ;
#     powla:hasLabel "case" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/dependency> ;
#     powla:hasSource <http://latinphilosophy.org/token/expr-0/6> ;
#     powla:hasTarget <http://latinphilosophy.org/token/expr-0/5> .
#
# <http://latinphilosophy.org/deprel/expr-0/6-7> a powla:Relation ;
#     rdfs:label "deprel: advmod" ;
#     powla:hasLabel "advmod" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/dependency> ;
#     powla:hasSource <http://latinphilosophy.org/token/expr-0/6> ;
#     powla:hasTarget <http://latinphilosophy.org/token/expr-0/7> .
#
# <http://latinphilosophy.org/deprel/expr-1/2-1> a powla:Relation ;
#     rdfs:label "deprel: case" ;
#     powla:hasLabel "case" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/dependency> ;
#     powla:hasSource <http://latinphilosophy.org/token/expr-1/2> ;
#     powla:hasTarget <http://latinphilosophy.org/token/expr-1/1> .
#
# <http://latinphilosophy.org/deprel/expr-1/2-3> a powla:Relation ;
#     rdfs:label "deprel: advmod" ;
#     powla:hasLabel "advmod" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/dependency> ;
#     powla:hasSource <http://latinphilosophy.org/token/expr-1/2> ;
#     powla:hasTarget <http://latinphilosophy.org/token/expr-1/3> .
#
# <http://latinphilosophy.org/deprel/expr-1/2-5> a powla:Relation ;
#     rdfs:label "deprel: obl" ;
#     powla:hasLabel "obl" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/dependency> ;
#     powla:hasSource <http://latinphilosophy.org/token/expr-1/2> ;
#     powla:hasTarget <http://latinphilosophy.org/token/expr-1/5> .
#
# <http://latinphilosophy.org/deprel/expr-1/5-4> a powla:Relation ;
#     rdfs:label "deprel: case" ;
#     powla:hasLabel "case" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/dependency> ;
#     powla:hasSource <http://latinphilosophy.org/token/expr-1/5> ;
#     powla:hasTarget <http://latinphilosophy.org/token/expr-1/4> .
#
# <http://latinphilosophy.org/deprel/expr-1/5-7> a powla:Relation ;
#     rdfs:label "deprel: nmod" ;
#     powla:hasLabel "nmod" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/dependency> ;
#     powla:hasSource <http://latinphilosophy.org/token/expr-1/5> ;
#     powla:hasTarget <http://latinphilosophy.org/token/expr-1/7> .
#
# <http://latinphilosophy.org/deprel/expr-1/7-6> a powla:Relation ;
#     rdfs:label "deprel: case" ;
#     powla:hasLabel "case" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/dependency> ;
#     powla:hasSource <http://latinphilosophy.org/token/expr-1/7> ;
#     powla:hasTarget <http://latinphilosophy.org/token/expr-1/6> .
#
# <http://latinphilosophy.org/deprel/expr-2/2-1> a powla:Relation ;
#     rdfs:label "deprel: case" ;
#     powla:hasLabel "case" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/dependency> ;
#     powla:hasSource <http://latinphilosophy.org/token/expr-2/2> ;
#     powla:hasTarget <http://latinphilosophy.org/token/expr-2/1> .
#
# <http://latinphilosophy.org/deprel/expr-3/2-1> a powla:Relation ;
#     rdfs:label "deprel: case" ;
#     powla:hasLabel "case" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/dependency> ;
#     powla:hasSource <http://latinphilosophy.org/token/expr-3/2> ;
#     powla:hasTarget <http://latinphilosophy.org/token/expr-3/1> .
#
# <http://latinphilosophy.org/deprel/expr-3/2-4> a powla:Relation ;
#     rdfs:label "deprel: cop" ;
#     powla:hasLabel "cop" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/dependency> ;
#     powla:hasSource <http://latinphilosophy.org/token/expr-3/2> ;
#     powla:hasTarget <http://latinphilosophy.org/token/expr-3/4> .
#
# <http://latinphilosophy.org/deprel/expr-3/4-3> a powla:Relation ;
#     rdfs:label "deprel: case" ;
#     powla:hasLabel "case" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/dependency> ;
#     powla:hasSource <http://latinphilosophy.org/token/expr-3/4> ;
#     powla:hasTarget <http://latinphilosophy.org/token/expr-3/3> .
#
# <http://latinphilosophy.org/deprel/expr-3/5-2> a powla:Relation ;
#     rdfs:label "deprel: obl" ;
#     powla:hasLabel "obl" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/dependency> ;
#     powla:hasSource <http://latinphilosophy.org/token/expr-3/5> ;
#     powla:hasTarget <http://latinphilosophy.org/token/expr-3/2> .
#
# <http://latinphilosophy.org/deprel/expr-3/5-6> a powla:Relation ;
#     rdfs:label "deprel: nsubj" ;
#     powla:hasLabel "nsubj" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/dependency> ;
#     powla:hasSource <http://latinphilosophy.org/token/expr-3/5> ;
#     powla:hasTarget <http://latinphilosophy.org/token/expr-3/6> .
#
# <http://latinphilosophy.org/deprel/expr-4/2-1> a powla:Relation ;
#     rdfs:label "deprel: case" ;
#     powla:hasLabel "case" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/dependency> ;
#     powla:hasSource <http://latinphilosophy.org/token/expr-4/2> ;
#     powla:hasTarget <http://latinphilosophy.org/token/expr-4/1> .
#
# <http://latinphilosophy.org/deprel/expr-5/2-1> a powla:Relation ;
#     rdfs:label "deprel: case" ;
#     powla:hasLabel "case" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/dependency> ;
#     powla:hasSource <http://latinphilosophy.org/token/expr-5/2> ;
#     powla:hasTarget <http://latinphilosophy.org/token/expr-5/1> .
#
# <http://latinphilosophy.org/deprel/expr-6/2-1> a powla:Relation ;
#     rdfs:label "deprel: case" ;
#     powla:hasLabel "case" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/dependency> ;
#     powla:hasSource <http://latinphilosophy.org/token/expr-6/2> ;
#     powla:hasTarget <http://latinphilosophy.org/token/expr-6/1> .
#
# <http://latinphilosophy.org/deprel/expr-6/4-3> a powla:Relation ;
#     rdfs:label "deprel: case" ;
#     powla:hasLabel "case" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/dependency> ;
#     powla:hasSource <http://latinphilosophy.org/token/expr-6/4> ;
#     powla:hasTarget <http://latinphilosophy.org/token/expr-6/3> .
#
# <http://latinphilosophy.org/deprel/expr-6/5-2> a powla:Relation ;
#     rdfs:label "deprel: obl" ;
#     powla:hasLabel "obl" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/dependency> ;
#     powla:hasSource <http://latinphilosophy.org/token/expr-6/5> ;
#     powla:hasTarget <http://latinphilosophy.org/token/expr-6/2> .
#
# <http://latinphilosophy.org/deprel/expr-6/5-4> a powla:Relation ;
#     rdfs:label "deprel: advcl" ;
#     powla:hasLabel "advcl" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/dependency> ;
#     powla:hasSource <http://latinphilosophy.org/token/expr-6/5> ;
#     powla:hasTarget <http://latinphilosophy.org/token/expr-6/4> .
#
# <http://latinphilosophy.org/deprel/expr-6/5-6> a powla:Relation ;
#     rdfs:label "deprel: nsubj" ;
#     powla:hasLabel "nsubj" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/dependency> ;
#     powla:hasSource <http://latinphilosophy.org/token/expr-6/5> ;
#     powla:hasTarget <http://latinphilosophy.org/token/expr-6/6> .
#
# <http://latinphilosophy.org/deprel/expr-7/2-1> a powla:Relation ;
#     rdfs:label "deprel: case" ;
#     powla:hasLabel "case" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/dependency> ;
#     powla:hasSource <http://latinphilosophy.org/token/expr-7/2> ;
#     powla:hasTarget <http://latinphilosophy.org/token/expr-7/1> .
#
# <http://latinphilosophy.org/deprel/expr-8/1-2> a powla:Relation ;
#     rdfs:label "deprel: amod" ;
#     powla:hasLabel "amod" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/dependency> ;
#     powla:hasSource <http://latinphilosophy.org/token/expr-8/1> ;
#     powla:hasTarget <http://latinphilosophy.org/token/expr-8/2> .
#
# <http://latinphilosophy.org/deprel/expr-9/2-1> a powla:Relation ;
#     rdfs:label "deprel: case" ;
#     powla:hasLabel "case" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/dependency> ;
#     powla:hasSource <http://latinphilosophy.org/token/expr-9/2> ;
#     powla:hasTarget <http://latinphilosophy.org/token/expr-9/1> .
#
# <http://latinphilosophy.org/semantics/expr-0> a powla:Node ;
#     rdfs:label "Semantic annotation of a dicto secundum quid ad dictum simpliciter" ;
#     dc:subject <http://latinphilosophy.org/concept/0> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/semantics> .
#
# <http://latinphilosophy.org/semantics/expr-1> a powla:Node ;
#     rdfs:label "Semantic annotation of a dicto simpliciter ad dictum secundum quid" ;
#     dc:subject <http://latinphilosophy.org/concept/1> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/semantics> .
#
# <http://latinphilosophy.org/semantics/expr-2> a powla:Node ;
#     rdfs:label "Semantic annotation of a fortiori" ;
#     dc:subject <http://latinphilosophy.org/concept/2> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/semantics> .
#
# <http://latinphilosophy.org/semantics/expr-3> a powla:Node ;
#     rdfs:label "Semantic annotation of a necesse ad esse valet consequentia" ;
#     dc:subject <http://latinphilosophy.org/concept/3> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/semantics> .
#
# <http://latinphilosophy.org/semantics/expr-4> a powla:Node ;
#     rdfs:label "Semantic annotation of a posteriori" ;
#     dc:subject <http://latinphilosophy.org/concept/4> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/semantics> .
#
# <http://latinphilosophy.org/semantics/expr-5> a powla:Node ;
#     rdfs:label "Semantic annotation of a priori" ;
#     dc:subject <http://latinphilosophy.org/concept/5> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/semantics> .
#
# <http://latinphilosophy.org/semantics/expr-6> a powla:Node ;
#     rdfs:label "Semantic annotation of ab esse ad posse valet consequentia" ;
#     dc:subject <http://latinphilosophy.org/concept/6> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/semantics> .
#
# <http://latinphilosophy.org/semantics/expr-7> a powla:Node ;
#     rdfs:label "Semantic annotation of ab ovo" ;
#     dc:subject <http://latinphilosophy.org/concept/7> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/semantics> .
#
# <http://latinphilosophy.org/semantics/expr-8> a powla:Node ;
#     rdfs:label "Semantic annotation of actus purus" ;
#     dc:subject <http://latinphilosophy.org/concept/8> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/semantics> .
#
# <http://latinphilosophy.org/semantics/expr-9> a powla:Node ;
#     rdfs:label "Semantic annotation of ad hoc" ;
#     dc:subject <http://latinphilosophy.org/concept/9> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/semantics> .
#
# <http://latinphilosophy.org/translation/0> a vartrans:Translation ;
#     rdfs:label "Translation of a dicto secundum quid ad dictum simpliciter" ;
#     vartrans:source <http://latinphilosophy.org/expression/la/0> ;
#     vartrans:target <http://latinphilosophy.org/expression/en/0> .
#
# <http://latinphilosophy.org/translation/1> a vartrans:Translation ;
#     rdfs:label "Translation of a dicto simpliciter ad dictum secundum quid" ;
#     vartrans:source <http://latinphilosophy.org/expression/la/1> ;
#     vartrans:target <http://latinphilosophy.org/expression/en/1> .
#
# <http://latinphilosophy.org/translation/2> a vartrans:Translation ;
#     rdfs:label "Translation of a fortiori" ;
#     vartrans:source <http://latinphilosophy.org/expression/la/2> ;
#     vartrans:target <http://latinphilosophy.org/expression/en/2> .
#
# <http://latinphilosophy.org/translation/3> a vartrans:Translation ;
#     rdfs:label "Translation of a necesse ad esse valet consequentia" ;
#     vartrans:source <http://latinphilosophy.org/expression/la/3> ;
#     vartrans:target <http://latinphilosophy.org/expression/en/3> .
#
# <http://latinphilosophy.org/translation/4> a vartrans:Translation ;
#     rdfs:label "Translation of a posteriori" ;
#     vartrans:source <http://latinphilosophy.org/expression/la/4> ;
#     vartrans:target <http://latinphilosophy.org/expression/en/4> .
#
# <http://latinphilosophy.org/translation/5> a vartrans:Translation ;
#     rdfs:label "Translation of a priori" ;
#     vartrans:source <http://latinphilosophy.org/expression/la/5> ;
#     vartrans:target <http://latinphilosophy.org/expression/en/5> .
#
# <http://latinphilosophy.org/translation/6> a vartrans:Translation ;
#     rdfs:label "Translation of ab esse ad posse valet consequentia" ;
#     vartrans:source <http://latinphilosophy.org/expression/la/6> ;
#     vartrans:target <http://latinphilosophy.org/expression/en/6> .
#
# <http://latinphilosophy.org/translation/7> a vartrans:Translation ;
#     rdfs:label "Translation of ab ovo" ;
#     vartrans:source <http://latinphilosophy.org/expression/la/7> ;
#     vartrans:target <http://latinphilosophy.org/expression/en/7> .
#
# <http://latinphilosophy.org/translation/8> a vartrans:Translation ;
#     rdfs:label "Translation of actus purus" ;
#     vartrans:source <http://latinphilosophy.org/expression/la/8> ;
#     vartrans:target <http://latinphilosophy.org/expression/en/8> .
#
# <http://latinphilosophy.org/translation/9> a vartrans:Translation ;
#     rdfs:label "Translation of ad hoc" ;
#     vartrans:source <http://latinphilosophy.org/expression/la/9> ;
#     vartrans:target <http://latinphilosophy.org/expression/en/9> .
#
# <http://latinphilosophy.org/ud/expr-0/1> a oa:annotation ;
#     rdfs:label "UD annotation of a" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/ud> ;
#     oa:hasBody <http://latinphilosophy.org/feat/adptype=prep>,
#         <http://latinphilosophy.org/pos/adp> ;
#     oa:hasTarget <http://latinphilosophy.org/token/expr-0/1> .
#
# <http://latinphilosophy.org/ud/expr-0/2> a oa:annotation ;
#     rdfs:label "UD annotation of dicto" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/ud> ;
#     oa:hasBody <http://latinphilosophy.org/feat/case=abl>,
#         <http://latinphilosophy.org/feat/gender=neut>,
#         <http://latinphilosophy.org/feat/number=sing>,
#         <http://latinphilosophy.org/pos/noun> ;
#     oa:hasTarget <http://latinphilosophy.org/token/expr-0/2> .
#
# <http://latinphilosophy.org/ud/expr-0/3> a oa:annotation ;
#     rdfs:label "UD annotation of secundum" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/ud> ;
#     oa:hasBody <http://latinphilosophy.org/feat/adptype=prep>,
#         <http://latinphilosophy.org/pos/adp> ;
#     oa:hasTarget <http://latinphilosophy.org/token/expr-0/3> .
#
# <http://latinphilosophy.org/ud/expr-0/4> a oa:annotation ;
#     rdfs:label "UD annotation of quid" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/ud> ;
#     oa:hasBody <http://latinphilosophy.org/feat/case=acc>,
#         <http://latinphilosophy.org/feat/gender=neut>,
#         <http://latinphilosophy.org/feat/number=sing>,
#         <http://latinphilosophy.org/feat/prontype=ind>,
#         <http://latinphilosophy.org/pos/pron> ;
#     oa:hasTarget <http://latinphilosophy.org/token/expr-0/4> .
#
# <http://latinphilosophy.org/ud/expr-0/5> a oa:annotation ;
#     rdfs:label "UD annotation of ad" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/ud> ;
#     oa:hasBody <http://latinphilosophy.org/feat/adptype=prep>,
#         <http://latinphilosophy.org/pos/adp> ;
#     oa:hasTarget <http://latinphilosophy.org/token/expr-0/5> .
#
# <http://latinphilosophy.org/ud/expr-0/6> a oa:annotation ;
#     rdfs:label "UD annotation of dictum" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/ud> ;
#     oa:hasBody <http://latinphilosophy.org/feat/aspect=perf>,
#         <http://latinphilosophy.org/feat/case=acc>,
#         <http://latinphilosophy.org/feat/gender=neut>,
#         <http://latinphilosophy.org/feat/number=sing>,
#         <http://latinphilosophy.org/feat/verbform=part>,
#         <http://latinphilosophy.org/feat/voice=pass>,
#         <http://latinphilosophy.org/pos/noun> ;
#     oa:hasTarget <http://latinphilosophy.org/token/expr-0/6> .
#
# <http://latinphilosophy.org/ud/expr-0/7> a oa:annotation ;
#     rdfs:label "UD annotation of simpliciter" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/ud> ;
#     oa:hasBody <http://latinphilosophy.org/pos/adv> ;
#     oa:hasTarget <http://latinphilosophy.org/token/expr-0/7> .
#
# <http://latinphilosophy.org/ud/expr-1/1> a oa:annotation ;
#     rdfs:label "UD annotation of a" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/ud> ;
#     oa:hasBody <http://latinphilosophy.org/feat/adptype=prep>,
#         <http://latinphilosophy.org/pos/adp> ;
#     oa:hasTarget <http://latinphilosophy.org/token/expr-1/1> .
#
# <http://latinphilosophy.org/ud/expr-1/2> a oa:annotation ;
#     rdfs:label "UD annotation of dicto" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/ud> ;
#     oa:hasBody <http://latinphilosophy.org/feat/case=abl>,
#         <http://latinphilosophy.org/feat/gender=neut>,
#         <http://latinphilosophy.org/feat/number=sing>,
#         <http://latinphilosophy.org/pos/noun> ;
#     oa:hasTarget <http://latinphilosophy.org/token/expr-1/2> .
#
# <http://latinphilosophy.org/ud/expr-1/3> a oa:annotation ;
#     rdfs:label "UD annotation of simpliciter" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/ud> ;
#     oa:hasBody <http://latinphilosophy.org/pos/adv> ;
#     oa:hasTarget <http://latinphilosophy.org/token/expr-1/3> .
#
# <http://latinphilosophy.org/ud/expr-1/4> a oa:annotation ;
#     rdfs:label "UD annotation of ad" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/ud> ;
#     oa:hasBody <http://latinphilosophy.org/feat/adptype=prep>,
#         <http://latinphilosophy.org/pos/adp> ;
#     oa:hasTarget <http://latinphilosophy.org/token/expr-1/4> .
#
# <http://latinphilosophy.org/ud/expr-1/5> a oa:annotation ;
#     rdfs:label "UD annotation of dictum" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/ud> ;
#     oa:hasBody <http://latinphilosophy.org/feat/case=acc>,
#         <http://latinphilosophy.org/feat/gender=neut>,
#         <http://latinphilosophy.org/feat/number=sing>,
#         <http://latinphilosophy.org/pos/noun> ;
#     oa:hasTarget <http://latinphilosophy.org/token/expr-1/5> .
#
# <http://latinphilosophy.org/ud/expr-1/6> a oa:annotation ;
#     rdfs:label "UD annotation of secundum" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/ud> ;
#     oa:hasBody <http://latinphilosophy.org/feat/adptype=prep>,
#         <http://latinphilosophy.org/pos/adp> ;
#     oa:hasTarget <http://latinphilosophy.org/token/expr-1/6> .
#
# <http://latinphilosophy.org/ud/expr-1/7> a oa:annotation ;
#     rdfs:label "UD annotation of quid" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/ud> ;
#     oa:hasBody <http://latinphilosophy.org/feat/case=acc>,
#         <http://latinphilosophy.org/feat/gender=neut>,
#         <http://latinphilosophy.org/feat/number=sing>,
#         <http://latinphilosophy.org/feat/prontype=ind>,
#         <http://latinphilosophy.org/pos/pron> ;
#     oa:hasTarget <http://latinphilosophy.org/token/expr-1/7> .
#
# <http://latinphilosophy.org/ud/expr-2/1> a oa:annotation ;
#     rdfs:label "UD annotation of a" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/ud> ;
#     oa:hasBody <http://latinphilosophy.org/feat/adptype=prep>,
#         <http://latinphilosophy.org/pos/adp> ;
#     oa:hasTarget <http://latinphilosophy.org/token/expr-2/1> .
#
# <http://latinphilosophy.org/ud/expr-2/2> a oa:annotation ;
#     rdfs:label "UD annotation of fortiori" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/ud> ;
#     oa:hasBody <http://latinphilosophy.org/feat/case=abl>,
#         <http://latinphilosophy.org/feat/degree=cmp>,
#         <http://latinphilosophy.org/feat/gender=masc>,
#         <http://latinphilosophy.org/feat/number=sing>,
#         <http://latinphilosophy.org/pos/adj> ;
#     oa:hasTarget <http://latinphilosophy.org/token/expr-2/2> .
#
# <http://latinphilosophy.org/ud/expr-3/1> a oa:annotation ;
#     rdfs:label "UD annotation of a" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/ud> ;
#     oa:hasBody <http://latinphilosophy.org/pos/adp> ;
#     oa:hasTarget <http://latinphilosophy.org/token/expr-3/1> .
#
# <http://latinphilosophy.org/ud/expr-3/2> a oa:annotation ;
#     rdfs:label "UD annotation of necesse" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/ud> ;
#     oa:hasBody <http://latinphilosophy.org/pos/adv> ;
#     oa:hasTarget <http://latinphilosophy.org/token/expr-3/2> .
#
# <http://latinphilosophy.org/ud/expr-3/3> a oa:annotation ;
#     rdfs:label "UD annotation of ad" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/ud> ;
#     oa:hasBody <http://latinphilosophy.org/feat/adptype=prep>,
#         <http://latinphilosophy.org/pos/adp> ;
#     oa:hasTarget <http://latinphilosophy.org/token/expr-3/3> .
#
# <http://latinphilosophy.org/ud/expr-3/4> a oa:annotation ;
#     rdfs:label "UD annotation of esse" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/ud> ;
#     oa:hasBody <http://latinphilosophy.org/feat/aspect=imp>,
#         <http://latinphilosophy.org/feat/verbform=inf>,
#         <http://latinphilosophy.org/pos/aux> ;
#     oa:hasTarget <http://latinphilosophy.org/token/expr-3/4> .
#
# <http://latinphilosophy.org/ud/expr-3/5> a oa:annotation ;
#     rdfs:label "UD annotation of valet" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/ud> ;
#     oa:hasBody <http://latinphilosophy.org/feat/aspect=imp>,
#         <http://latinphilosophy.org/feat/mood=ind>,
#         <http://latinphilosophy.org/feat/number=sing>,
#         <http://latinphilosophy.org/feat/person=3>,
#         <http://latinphilosophy.org/feat/tense=pres>,
#         <http://latinphilosophy.org/feat/verbform=fin>,
#         <http://latinphilosophy.org/feat/voice=act>,
#         <http://latinphilosophy.org/pos/verb> ;
#     oa:hasTarget <http://latinphilosophy.org/token/expr-3/5> .
#
# <http://latinphilosophy.org/ud/expr-3/6> a oa:annotation ;
#     rdfs:label "UD annotation of consequentia" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/ud> ;
#     oa:hasBody <http://latinphilosophy.org/feat/case=nom>,
#         <http://latinphilosophy.org/feat/gender=fem>,
#         <http://latinphilosophy.org/feat/number=sing>,
#         <http://latinphilosophy.org/pos/noun> ;
#     oa:hasTarget <http://latinphilosophy.org/token/expr-3/6> .
#
# <http://latinphilosophy.org/ud/expr-4/1> a oa:annotation ;
#     rdfs:label "UD annotation of a" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/ud> ;
#     oa:hasBody <http://latinphilosophy.org/feat/adptype=prep>,
#         <http://latinphilosophy.org/pos/adp> ;
#     oa:hasTarget <http://latinphilosophy.org/token/expr-4/1> .
#
# <http://latinphilosophy.org/ud/expr-4/2> a oa:annotation ;
#     rdfs:label "UD annotation of posteriori" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/ud> ;
#     oa:hasBody <http://latinphilosophy.org/feat/case=abl>,
#         <http://latinphilosophy.org/feat/degree=cmp>,
#         <http://latinphilosophy.org/feat/gender=masc>,
#         <http://latinphilosophy.org/feat/number=sing>,
#         <http://latinphilosophy.org/pos/adj> ;
#     oa:hasTarget <http://latinphilosophy.org/token/expr-4/2> .
#
# <http://latinphilosophy.org/ud/expr-5/1> a oa:annotation ;
#     rdfs:label "UD annotation of a" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/ud> ;
#     oa:hasBody <http://latinphilosophy.org/feat/adptype=prep>,
#         <http://latinphilosophy.org/pos/adp> ;
#     oa:hasTarget <http://latinphilosophy.org/token/expr-5/1> .
#
# <http://latinphilosophy.org/ud/expr-5/2> a oa:annotation ;
#     rdfs:label "UD annotation of priori" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/ud> ;
#     oa:hasBody <http://latinphilosophy.org/feat/case=abl>,
#         <http://latinphilosophy.org/feat/degree=cmp>,
#         <http://latinphilosophy.org/feat/gender=masc>,
#         <http://latinphilosophy.org/feat/number=sing>,
#         <http://latinphilosophy.org/pos/adj> ;
#     oa:hasTarget <http://latinphilosophy.org/token/expr-5/2> .
#
# <http://latinphilosophy.org/ud/expr-6/1> a oa:annotation ;
#     rdfs:label "UD annotation of ab" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/ud> ;
#     oa:hasBody <http://latinphilosophy.org/feat/adptype=prep>,
#         <http://latinphilosophy.org/pos/adp> ;
#     oa:hasTarget <http://latinphilosophy.org/token/expr-6/1> .
#
# <http://latinphilosophy.org/ud/expr-6/2> a oa:annotation ;
#     rdfs:label "UD annotation of esse" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/ud> ;
#     oa:hasBody <http://latinphilosophy.org/feat/aspect=imp>,
#         <http://latinphilosophy.org/feat/verbform=inf>,
#         <http://latinphilosophy.org/pos/aux> ;
#     oa:hasTarget <http://latinphilosophy.org/token/expr-6/2> .
#
# <http://latinphilosophy.org/ud/expr-6/3> a oa:annotation ;
#     rdfs:label "UD annotation of ad" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/ud> ;
#     oa:hasBody <http://latinphilosophy.org/feat/adptype=prep>,
#         <http://latinphilosophy.org/pos/adp> ;
#     oa:hasTarget <http://latinphilosophy.org/token/expr-6/3> .
#
# <http://latinphilosophy.org/ud/expr-6/4> a oa:annotation ;
#     rdfs:label "UD annotation of posse" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/ud> ;
#     oa:hasBody <http://latinphilosophy.org/feat/aspect=imp>,
#         <http://latinphilosophy.org/feat/verbform=inf>,
#         <http://latinphilosophy.org/feat/voice=act>,
#         <http://latinphilosophy.org/pos/verb> ;
#     oa:hasTarget <http://latinphilosophy.org/token/expr-6/4> .
#
# <http://latinphilosophy.org/ud/expr-6/5> a oa:annotation ;
#     rdfs:label "UD annotation of valet" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/ud> ;
#     oa:hasBody <http://latinphilosophy.org/feat/aspect=imp>,
#         <http://latinphilosophy.org/feat/mood=ind>,
#         <http://latinphilosophy.org/feat/number=sing>,
#         <http://latinphilosophy.org/feat/person=3>,
#         <http://latinphilosophy.org/feat/tense=pres>,
#         <http://latinphilosophy.org/feat/verbform=fin>,
#         <http://latinphilosophy.org/feat/voice=act>,
#         <http://latinphilosophy.org/pos/verb> ;
#     oa:hasTarget <http://latinphilosophy.org/token/expr-6/5> .
#
# <http://latinphilosophy.org/ud/expr-6/6> a oa:annotation ;
#     rdfs:label "UD annotation of consequentia" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/ud> ;
#     oa:hasBody <http://latinphilosophy.org/feat/case=nom>,
#         <http://latinphilosophy.org/feat/gender=fem>,
#         <http://latinphilosophy.org/feat/number=sing>,
#         <http://latinphilosophy.org/pos/noun> ;
#     oa:hasTarget <http://latinphilosophy.org/token/expr-6/6> .
#
# <http://latinphilosophy.org/ud/expr-7/1> a oa:annotation ;
#     rdfs:label "UD annotation of ab" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/ud> ;
#     oa:hasBody <http://latinphilosophy.org/feat/adptype=prep>,
#         <http://latinphilosophy.org/pos/adp> ;
#     oa:hasTarget <http://latinphilosophy.org/token/expr-7/1> .
#
# <http://latinphilosophy.org/ud/expr-7/2> a oa:annotation ;
#     rdfs:label "UD annotation of ovo" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/ud> ;
#     oa:hasBody <http://latinphilosophy.org/feat/case=abl>,
#         <http://latinphilosophy.org/feat/gender=neut>,
#         <http://latinphilosophy.org/feat/number=sing>,
#         <http://latinphilosophy.org/pos/noun> ;
#     oa:hasTarget <http://latinphilosophy.org/token/expr-7/2> .
#
# <http://latinphilosophy.org/ud/expr-8/1> a oa:annotation ;
#     rdfs:label "UD annotation of actus" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/ud> ;
#     oa:hasBody <http://latinphilosophy.org/feat/case=nom>,
#         <http://latinphilosophy.org/feat/gender=masc>,
#         <http://latinphilosophy.org/feat/number=sing>,
#         <http://latinphilosophy.org/pos/noun> ;
#     oa:hasTarget <http://latinphilosophy.org/token/expr-8/1> .
#
# <http://latinphilosophy.org/ud/expr-8/2> a oa:annotation ;
#     rdfs:label "UD annotation of purus" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/ud> ;
#     oa:hasBody <http://latinphilosophy.org/feat/case=nom>,
#         <http://latinphilosophy.org/feat/gender=masc>,
#         <http://latinphilosophy.org/feat/number=sing>,
#         <http://latinphilosophy.org/pos/adj> ;
#     oa:hasTarget <http://latinphilosophy.org/token/expr-8/2> .
#
# <http://latinphilosophy.org/ud/expr-9/1> a oa:annotation ;
#     rdfs:label "UD annotation of ad" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/ud> ;
#     oa:hasBody <http://latinphilosophy.org/feat/adptype=prep>,
#         <http://latinphilosophy.org/pos/adp> ;
#     oa:hasTarget <http://latinphilosophy.org/token/expr-9/1> .
#
# <http://latinphilosophy.org/ud/expr-9/2> a oa:annotation ;
#     rdfs:label "UD annotation of hoc" ;
#     powla:hasLayer <http://latinphilosophy.org/layer/ud> ;
#     oa:hasBody <http://latinphilosophy.org/feat/case=acc>,
#         <http://latinphilosophy.org/feat/gender=neut>,
#         <http://latinphilosophy.org/feat/number=sing>,
#         <http://latinphilosophy.org/feat/prontype=dem>,
#         <http://latinphilosophy.org/pos/det> ;
#     oa:hasTarget <http://latinphilosophy.org/token/expr-9/2> .
#
# <https://universaldependencies.org/la/feat/Adptype#Prep> rdfs:label "Adptype=Prep" ;
#     dc:title "Adptype#Prep" .
#
# <https://universaldependencies.org/la/feat/Aspect#Imp> rdfs:label "Aspect=Imp" ;
#     dc:title "Aspect#Imp" .
#
# <https://universaldependencies.org/la/feat/Aspect#Perf> rdfs:label "Aspect=Perf" ;
#     dc:title "Aspect#Perf" .
#
# <https://universaldependencies.org/la/feat/Case#Abl> rdfs:label "Case=Abl" ;
#     dc:title "Case#Abl" .
#
# <https://universaldependencies.org/la/feat/Case#Acc> rdfs:label "Case=Acc" ;
#     dc:title "Case#Acc" .
#
# <https://universaldependencies.org/la/feat/Case#Nom> rdfs:label "Case=Nom" ;
#     dc:title "Case#Nom" .
#
# <https://universaldependencies.org/la/feat/Degree#Cmp> rdfs:label "Degree=Cmp" ;
#     dc:title "Degree#Cmp" .
#
# <https://universaldependencies.org/la/feat/Gender#Fem> rdfs:label "Gender=Fem" ;
#     dc:title "Gender#Fem" .
#
# <https://universaldependencies.org/la/feat/Gender#Masc> rdfs:label "Gender=Masc" ;
#     dc:title "Gender#Masc" .
#
# <https://universaldependencies.org/la/feat/Gender#Neut> rdfs:label "Gender=Neut" ;
#     dc:title "Gender#Neut" .
#
# <https://universaldependencies.org/la/feat/Mood#Ind> rdfs:label "Mood=Ind" ;
#     dc:title "Mood#Ind" .
#
# <https://universaldependencies.org/la/feat/Number#Sing> rdfs:label "Number=Sing" ;
#     dc:title "Number#Sing" .
#
# <https://universaldependencies.org/la/feat/Person#3> rdfs:label "Person=3" ;
#     dc:title "Person#3" .
#
# <https://universaldependencies.org/la/feat/Prontype#Dem> rdfs:label "Prontype=Dem" ;
#     dc:title "Prontype#Dem" .
#
# <https://universaldependencies.org/la/feat/Prontype#Ind> rdfs:label "Prontype=Ind" ;
#     dc:title "Prontype#Ind" .
#
# <https://universaldependencies.org/la/feat/Tense#Pres> rdfs:label "Tense=Pres" ;
#     dc:title "Tense#Pres" .
#
# <https://universaldependencies.org/la/feat/Verbform#Fin> rdfs:label "Verbform=Fin" ;
#     dc:title "Verbform#Fin" .
#
# <https://universaldependencies.org/la/feat/Verbform#Inf> rdfs:label "Verbform=Inf" ;
#     dc:title "Verbform#Inf" .
#
# <https://universaldependencies.org/la/feat/Verbform#Part> rdfs:label "Verbform=Part" ;
#     dc:title "Verbform#Part" .
#
# <https://universaldependencies.org/la/feat/Voice#Act> rdfs:label "Voice=Act" ;
#     dc:title "Voice#Act" .
#
# <https://universaldependencies.org/la/feat/Voice#Pass> rdfs:label "Voice=Pass" ;
#     dc:title "Voice#Pass" .
#
# <http://latinphilosophy.org/branch/aesthetics> a skos:Concept ;
#     rdfs:seeAlso <https://www.wikidata.org/wiki/Q35986> ;
#     skos:prefLabel "Aesthetics"@en .
#
# <http://latinphilosophy.org/branch/metaphysics> a skos:Concept ;
#     rdfs:seeAlso <https://www.wikidata.org/wiki/Q35277> ;
#     skos:prefLabel "Metaphysics"@en .
#
# <http://latinphilosophy.org/concept/101> skos:related <http://latinphilosophy.org/concept/99> .
#
# <http://latinphilosophy.org/concept/124> skos:related <http://latinphilosophy.org/concept/125> .
#
# <http://latinphilosophy.org/concept/125> skos:related <http://latinphilosophy.org/concept/124> .
#
# <http://latinphilosophy.org/concept/144> skos:related <http://latinphilosophy.org/concept/92> .
#
# <http://latinphilosophy.org/concept/20> skos:related <http://latinphilosophy.org/concept/59> .
#
# <http://latinphilosophy.org/concept/59> skos:related <http://latinphilosophy.org/concept/20> .
#
# <http://latinphilosophy.org/concept/84> skos:related <http://latinphilosophy.org/concept/85> .
#
# <http://latinphilosophy.org/concept/85> skos:related <http://latinphilosophy.org/concept/84> .
#
# <http://latinphilosophy.org/concept/87> skos:related <http://latinphilosophy.org/concept/88> .
#
# <http://latinphilosophy.org/concept/88> skos:related <http://latinphilosophy.org/concept/87> .
#
# <http://latinphilosophy.org/concept/92> skos:related <http://latinphilosophy.org/concept/144> .
#
# <http://latinphilosophy.org/concept/99> skos:related <http://latinphilosophy.org/concept/101> .
#
# <http://latinphilosophy.org/expression/en/0> a ontolex:LexicalEntry ;
#     rdfs:label "from a statement qualified to a statement unqualified"@en ;
#     lime:entry <http://latinphilosophy.org/lexicon/en> ;
#     ontolex:canonicalForm <http://latinphilosophy.org/form/en/0> ;
#     ontolex:evokes <http://latinphilosophy.org/concept/0> .
#
# <http://latinphilosophy.org/expression/en/1> a ontolex:LexicalEntry ;
#     rdfs:label "from the saying absolutely to the saying with a qualification"@en ;
#     lime:entry <http://latinphilosophy.org/lexicon/en> ;
#     ontolex:canonicalForm <http://latinphilosophy.org/form/en/1> ;
#     ontolex:evokes <http://latinphilosophy.org/concept/1> .
#
# <http://latinphilosophy.org/expression/en/2> a ontolex:LexicalEntry ;
#     rdfs:label "a fortiori"@en ;
#     lime:entry <http://latinphilosophy.org/lexicon/en> ;
#     ontolex:canonicalForm <http://latinphilosophy.org/form/en/2> ;
#     ontolex:evokes <http://latinphilosophy.org/concept/2> .
#
# <http://latinphilosophy.org/expression/en/3> a ontolex:LexicalEntry ;
#     rdfs:label "From necessity to being, the consequence holds."@en ;
#     lime:entry <http://latinphilosophy.org/lexicon/en> ;
#     ontolex:canonicalForm <http://latinphilosophy.org/form/en/3> ;
#     ontolex:evokes <http://latinphilosophy.org/concept/3> .
#
# <http://latinphilosophy.org/expression/en/4> a ontolex:LexicalEntry ;
#     rdfs:label "from the latter"@en ;
#     lime:entry <http://latinphilosophy.org/lexicon/en> ;
#     ontolex:canonicalForm <http://latinphilosophy.org/form/en/4> ;
#     ontolex:evokes <http://latinphilosophy.org/concept/4> .
#
# <http://latinphilosophy.org/expression/en/5> a ontolex:LexicalEntry ;
#     rdfs:label "from the former"@en ;
#     lime:entry <http://latinphilosophy.org/lexicon/en> ;
#     ontolex:canonicalForm <http://latinphilosophy.org/form/en/5> ;
#     ontolex:evokes <http://latinphilosophy.org/concept/5> .
#
# <http://latinphilosophy.org/expression/en/6> a ontolex:LexicalEntry ;
#     rdfs:label "From being to possibility the consequence is valid"@en ;
#     lime:entry <http://latinphilosophy.org/lexicon/en> ;
#     ontolex:canonicalForm <http://latinphilosophy.org/form/en/6> ;
#     ontolex:evokes <http://latinphilosophy.org/concept/6> .
#
# <http://latinphilosophy.org/expression/en/7> a ontolex:LexicalEntry ;
#     rdfs:label "from the egg"@en ;
#     lime:entry <http://latinphilosophy.org/lexicon/en> ;
#     ontolex:canonicalForm <http://latinphilosophy.org/form/en/7> ;
#     ontolex:evokes <http://latinphilosophy.org/concept/7> .
#
# <http://latinphilosophy.org/expression/en/8> a ontolex:LexicalEntry ;
#     rdfs:label "pure act"@en ;
#     lime:entry <http://latinphilosophy.org/lexicon/en> ;
#     ontolex:canonicalForm <http://latinphilosophy.org/form/en/8> ;
#     ontolex:evokes <http://latinphilosophy.org/concept/8> .
#
# <http://latinphilosophy.org/expression/en/9> a ontolex:LexicalEntry ;
#     rdfs:label "for this purpose"@en ;
#     lime:entry <http://latinphilosophy.org/lexicon/en> ;
#     ontolex:canonicalForm <http://latinphilosophy.org/form/en/9> ;
#     ontolex:evokes <http://latinphilosophy.org/concept/9> .
#
# <http://latinphilosophy.org/expression/la/0> a powla:root,
#         ontolex:LexicalEntry ;
#     rdfs:label "a dicto secundum quid ad dictum simpliciter"@la ;
#     powla:first <http://latinphilosophy.org/token/expr-0/1> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/expression> ;
#     powla:hasTerminal <http://latinphilosophy.org/token/expr-0/1>,
#         <http://latinphilosophy.org/token/expr-0/2>,
#         <http://latinphilosophy.org/token/expr-0/3>,
#         <http://latinphilosophy.org/token/expr-0/4>,
#         <http://latinphilosophy.org/token/expr-0/5>,
#         <http://latinphilosophy.org/token/expr-0/6>,
#         <http://latinphilosophy.org/token/expr-0/7> ;
#     powla:last <http://latinphilosophy.org/token/expr-0/7> ;
#     lime:entry <http://latinphilosophy.org/lexicon/la> ;
#     ontolex:canonicalForm <http://latinphilosophy.org/form/la/0> ;
#     ontolex:evokes <http://latinphilosophy.org/concept/0> ;
#     ontolex:sense <http://latinphilosophy.org/sense/en/expr-0/aristotle>,
#         <http://latinphilosophy.org/sense/en/expr-0/immanuel-kant>,
#         <http://latinphilosophy.org/sense/en/expr-0/leibniz>,
#         <http://latinphilosophy.org/sense/en/expr-0/thomas-aquinas> .
#
# <http://latinphilosophy.org/expression/la/1> a powla:root,
#         ontolex:LexicalEntry ;
#     rdfs:label "a dicto simpliciter ad dictum secundum quid"@la ;
#     powla:first <http://latinphilosophy.org/token/expr-1/1> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/expression> ;
#     powla:hasTerminal <http://latinphilosophy.org/token/expr-1/1>,
#         <http://latinphilosophy.org/token/expr-1/2>,
#         <http://latinphilosophy.org/token/expr-1/3>,
#         <http://latinphilosophy.org/token/expr-1/4>,
#         <http://latinphilosophy.org/token/expr-1/5>,
#         <http://latinphilosophy.org/token/expr-1/6>,
#         <http://latinphilosophy.org/token/expr-1/7> ;
#     powla:last <http://latinphilosophy.org/token/expr-1/7> ;
#     lime:entry <http://latinphilosophy.org/lexicon/la> ;
#     ontolex:canonicalForm <http://latinphilosophy.org/form/la/1> ;
#     ontolex:evokes <http://latinphilosophy.org/concept/1> ;
#     ontolex:sense <http://latinphilosophy.org/sense/en/expr-1/aristotle>,
#         <http://latinphilosophy.org/sense/en/expr-1/david-hume>,
#         <http://latinphilosophy.org/sense/en/expr-1/immanuel-kant>,
#         <http://latinphilosophy.org/sense/en/expr-1/thomas-aquinas> .
#
# <http://latinphilosophy.org/expression/la/2> a powla:root,
#         ontolex:LexicalEntry ;
#     rdfs:label "a fortiori"@la ;
#     powla:first <http://latinphilosophy.org/token/expr-2/1> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/expression> ;
#     powla:hasTerminal <http://latinphilosophy.org/token/expr-2/1>,
#         <http://latinphilosophy.org/token/expr-2/2> ;
#     powla:last <http://latinphilosophy.org/token/expr-2/2> ;
#     lime:entry <http://latinphilosophy.org/lexicon/la> ;
#     ontolex:canonicalForm <http://latinphilosophy.org/form/la/2> ;
#     ontolex:evokes <http://latinphilosophy.org/concept/2> ;
#     ontolex:sense <http://latinphilosophy.org/sense/en/expr-2/aristotle>,
#         <http://latinphilosophy.org/sense/en/expr-2/david-hume>,
#         <http://latinphilosophy.org/sense/en/expr-2/immanuel-kant>,
#         <http://latinphilosophy.org/sense/en/expr-2/thomas-aquinas> .
#
# <http://latinphilosophy.org/expression/la/3> a powla:root,
#         ontolex:LexicalEntry ;
#     rdfs:label "a necesse ad esse valet consequentia"@la ;
#     powla:first <http://latinphilosophy.org/token/expr-3/1> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/expression> ;
#     powla:hasTerminal <http://latinphilosophy.org/token/expr-3/1>,
#         <http://latinphilosophy.org/token/expr-3/2>,
#         <http://latinphilosophy.org/token/expr-3/3>,
#         <http://latinphilosophy.org/token/expr-3/4>,
#         <http://latinphilosophy.org/token/expr-3/5>,
#         <http://latinphilosophy.org/token/expr-3/6> ;
#     powla:last <http://latinphilosophy.org/token/expr-3/6> ;
#     lime:entry <http://latinphilosophy.org/lexicon/la> ;
#     ontolex:canonicalForm <http://latinphilosophy.org/form/la/3> ;
#     ontolex:evokes <http://latinphilosophy.org/concept/3> ;
#     ontolex:sense <http://latinphilosophy.org/sense/en/expr-3/aristotle>,
#         <http://latinphilosophy.org/sense/en/expr-3/david-hume>,
#         <http://latinphilosophy.org/sense/en/expr-3/immanuel-kant>,
#         <http://latinphilosophy.org/sense/en/expr-3/thomas-aquinas> .
#
# <http://latinphilosophy.org/expression/la/4> a powla:root,
#         ontolex:LexicalEntry ;
#     rdfs:label "a posteriori"@la ;
#     powla:first <http://latinphilosophy.org/token/expr-4/1> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/expression> ;
#     powla:hasTerminal <http://latinphilosophy.org/token/expr-4/1>,
#         <http://latinphilosophy.org/token/expr-4/2> ;
#     powla:last <http://latinphilosophy.org/token/expr-4/2> ;
#     lime:entry <http://latinphilosophy.org/lexicon/la> ;
#     ontolex:canonicalForm <http://latinphilosophy.org/form/la/4> ;
#     ontolex:evokes <http://latinphilosophy.org/concept/4> ;
#     ontolex:sense <http://latinphilosophy.org/sense/en/expr-4/david-hume>,
#         <http://latinphilosophy.org/sense/en/expr-4/immanuel-kant>,
#         <http://latinphilosophy.org/sense/en/expr-4/john-stuart-mill>,
#         <http://latinphilosophy.org/sense/en/expr-4/leibniz> .
#
# <http://latinphilosophy.org/expression/la/5> a powla:root,
#         ontolex:LexicalEntry ;
#     rdfs:label "a priori"@la ;
#     powla:first <http://latinphilosophy.org/token/expr-5/1> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/expression> ;
#     powla:hasTerminal <http://latinphilosophy.org/token/expr-5/1>,
#         <http://latinphilosophy.org/token/expr-5/2> ;
#     powla:last <http://latinphilosophy.org/token/expr-5/2> ;
#     lime:entry <http://latinphilosophy.org/lexicon/la> ;
#     ontolex:canonicalForm <http://latinphilosophy.org/form/la/5> ;
#     ontolex:evokes <http://latinphilosophy.org/concept/5> ;
#     ontolex:sense <http://latinphilosophy.org/sense/en/expr-5/david-hume>,
#         <http://latinphilosophy.org/sense/en/expr-5/descartes>,
#         <http://latinphilosophy.org/sense/en/expr-5/gottlob-frege>,
#         <http://latinphilosophy.org/sense/en/expr-5/immanuel-kant> .
#
# <http://latinphilosophy.org/expression/la/6> a powla:root,
#         ontolex:LexicalEntry ;
#     rdfs:label "ab esse ad posse valet consequentia"@la ;
#     powla:first <http://latinphilosophy.org/token/expr-6/1> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/expression> ;
#     powla:hasTerminal <http://latinphilosophy.org/token/expr-6/1>,
#         <http://latinphilosophy.org/token/expr-6/2>,
#         <http://latinphilosophy.org/token/expr-6/3>,
#         <http://latinphilosophy.org/token/expr-6/4>,
#         <http://latinphilosophy.org/token/expr-6/5>,
#         <http://latinphilosophy.org/token/expr-6/6> ;
#     powla:last <http://latinphilosophy.org/token/expr-6/6> ;
#     lime:entry <http://latinphilosophy.org/lexicon/la> ;
#     ontolex:canonicalForm <http://latinphilosophy.org/form/la/6> ;
#     ontolex:evokes <http://latinphilosophy.org/concept/6> ;
#     ontolex:sense <http://latinphilosophy.org/sense/en/expr-6/aristotle>,
#         <http://latinphilosophy.org/sense/en/expr-6/immanuel-kant>,
#         <http://latinphilosophy.org/sense/en/expr-6/leibniz>,
#         <http://latinphilosophy.org/sense/en/expr-6/thomas-aquinas> .
#
# <http://latinphilosophy.org/expression/la/7> a powla:root,
#         ontolex:LexicalEntry ;
#     rdfs:label "ab ovo"@la ;
#     powla:first <http://latinphilosophy.org/token/expr-7/1> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/expression> ;
#     powla:hasTerminal <http://latinphilosophy.org/token/expr-7/1>,
#         <http://latinphilosophy.org/token/expr-7/2> ;
#     powla:last <http://latinphilosophy.org/token/expr-7/2> ;
#     lime:entry <http://latinphilosophy.org/lexicon/la> ;
#     ontolex:canonicalForm <http://latinphilosophy.org/form/la/7> ;
#     ontolex:evokes <http://latinphilosophy.org/concept/7> ;
#     ontolex:sense <http://latinphilosophy.org/sense/en/expr-7/aristotle>,
#         <http://latinphilosophy.org/sense/en/expr-7/hegel>,
#         <http://latinphilosophy.org/sense/en/expr-7/horace>,
#         <http://latinphilosophy.org/sense/en/expr-7/nietzsche> .
#
# <http://latinphilosophy.org/expression/la/8> a powla:root,
#         ontolex:LexicalEntry ;
#     rdfs:label "actus purus"@la ;
#     powla:first <http://latinphilosophy.org/token/expr-8/1> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/expression> ;
#     powla:hasTerminal <http://latinphilosophy.org/token/expr-8/1>,
#         <http://latinphilosophy.org/token/expr-8/2> ;
#     powla:last <http://latinphilosophy.org/token/expr-8/2> ;
#     lime:entry <http://latinphilosophy.org/lexicon/la> ;
#     ontolex:canonicalForm <http://latinphilosophy.org/form/la/8> ;
#     ontolex:evokes <http://latinphilosophy.org/concept/8> ;
#     ontolex:sense <http://latinphilosophy.org/sense/en/expr-8/aristotle>,
#         <http://latinphilosophy.org/sense/en/expr-8/hegel>,
#         <http://latinphilosophy.org/sense/en/expr-8/leibniz>,
#         <http://latinphilosophy.org/sense/en/expr-8/thomas-aquinas> .
#
# <http://latinphilosophy.org/expression/la/9> a powla:root,
#         ontolex:LexicalEntry ;
#     rdfs:label "ad hoc"@la ;
#     powla:first <http://latinphilosophy.org/token/expr-9/1> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/expression> ;
#     powla:hasTerminal <http://latinphilosophy.org/token/expr-9/1>,
#         <http://latinphilosophy.org/token/expr-9/2> ;
#     powla:last <http://latinphilosophy.org/token/expr-9/2> ;
#     lime:entry <http://latinphilosophy.org/lexicon/la> ;
#     ontolex:canonicalForm <http://latinphilosophy.org/form/la/9> ;
#     ontolex:evokes <http://latinphilosophy.org/concept/9> ;
#     ontolex:sense <http://latinphilosophy.org/sense/en/expr-9/aristotle>,
#         <http://latinphilosophy.org/sense/en/expr-9/david-hume>,
#         <http://latinphilosophy.org/sense/en/expr-9/karl-popper>,
#         <http://latinphilosophy.org/sense/en/expr-9/thomas-kuhn> .
#
# <http://latinphilosophy.org/feat/aspect=perf> a <https://universaldependencies.org/u/feat/Aspect#Perf> ;
#     rdfs:label "Aspect=Perf" .
#
# <http://latinphilosophy.org/feat/prontype=dem> a <https://universaldependencies.org/u/feat/Prontype#Dem> ;
#     rdfs:label "Prontype=Dem" .
#
# <http://latinphilosophy.org/feat/verbform=part> a <https://universaldependencies.org/u/feat/Verbform#Part> ;
#     rdfs:label "Verbform=Part" .
#
# <http://latinphilosophy.org/feat/voice=pass> a <https://universaldependencies.org/u/feat/Voice#Pass> ;
#     rdfs:label "Voice=Pass" .
#
# <http://latinphilosophy.org/form/en/0> a ontolex:Form ;
#     ontolex:writtenRep "From a statement qualified to a statement unqualified"@en .
#
# <http://latinphilosophy.org/form/en/1> a ontolex:Form ;
#     ontolex:writtenRep "From the saying absolutely to the saying with a qualification"@en .
#
# <http://latinphilosophy.org/form/en/2> a ontolex:Form ;
# ...
#     skos:related <http://latinphilosophy.org/concept/2>,
#         <http://latinphilosophy.org/concept/4> ;
#     ontolex:lexicalizedSense <http://latinphilosophy.org/sense/en/expr-5/david-hume>,
#         <http://latinphilosophy.org/sense/en/expr-5/descartes>,
#         <http://latinphilosophy.org/sense/en/expr-5/gottlob-frege>,
#         <http://latinphilosophy.org/sense/en/expr-5/immanuel-kant> .
#
# <http://latinphilosophy.org/feat/aspect=imp> a <https://universaldependencies.org/u/feat/Aspect#Imp> ;
#     rdfs:label "Aspect=Imp" .
#
# <http://latinphilosophy.org/feat/case=acc> a <https://universaldependencies.org/u/feat/Case#Acc> ;
#     rdfs:label "Case=Acc" .
#
# <http://latinphilosophy.org/feat/gender=masc> a <https://universaldependencies.org/u/feat/Gender#Masc> ;
#     rdfs:label "Gender=Masc" .
#
# <http://latinphilosophy.org/token/expr-0/1> a powla:Terminal ;
#     rdfs:label "a"@la ;
#     lila:hasLemma <http://lila-erc.eu/data/id/lemma/87344> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/document> ;
#     powla:next <http://latinphilosophy.org/token/expr-0/2> .
#
# <http://latinphilosophy.org/token/expr-0/3> a powla:Terminal ;
#     rdfs:label "secundum"@la ;
#     lila:hasLemma <http://lila-erc.eu/data/id/lemma/127508> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/document> ;
#     powla:next <http://latinphilosophy.org/token/expr-0/4> ;
#     powla:prev <http://latinphilosophy.org/token/expr-0/2> .
#
# <http://latinphilosophy.org/token/expr-0/5> a powla:Terminal ;
#     rdfs:label "ad"@la ;
#     lila:hasLemma <http://lila-erc.eu/data/id/lemma/87344> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/document> ;
#     powla:next <http://latinphilosophy.org/token/expr-0/6> ;
#     powla:prev <http://latinphilosophy.org/token/expr-0/4> .
#
# <http://latinphilosophy.org/token/expr-0/7> a powla:Terminal ;
#     rdfs:label "simpliciter"@la ;
#     lila:hasLemma <http://lila-erc.eu/data/id/lemma/40941> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/document> ;
#     powla:prev <http://latinphilosophy.org/token/expr-0/6> .
#
# <http://latinphilosophy.org/token/expr-1/1> a powla:Terminal ;
#     rdfs:label "a"@la ;
#     lila:hasLemma <http://lila-erc.eu/data/id/lemma/87344> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/document> ;
#     powla:next <http://latinphilosophy.org/token/expr-1/2> .
#
# <http://latinphilosophy.org/token/expr-1/3> a powla:Terminal ;
#     rdfs:label "simpliciter"@la ;
#     lila:hasLemma <http://lila-erc.eu/data/id/lemma/40941> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/document> ;
#     powla:next <http://latinphilosophy.org/token/expr-1/4> ;
#     powla:prev <http://latinphilosophy.org/token/expr-1/2> .
#
# <http://latinphilosophy.org/token/expr-1/4> a powla:Terminal ;
#     rdfs:label "ad"@la ;
#     lila:hasLemma <http://lila-erc.eu/data/id/lemma/87344> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/document> ;
#     powla:next <http://latinphilosophy.org/token/expr-1/5> ;
#     powla:prev <http://latinphilosophy.org/token/expr-1/3> .
#
# <http://latinphilosophy.org/token/expr-1/6> a powla:Terminal ;
#     rdfs:label "secundum"@la ;
#     lila:hasLemma <http://lila-erc.eu/data/id/lemma/127508> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/document> ;
#     powla:next <http://latinphilosophy.org/token/expr-1/7> ;
#     powla:prev <http://latinphilosophy.org/token/expr-1/5> .
#
# <http://latinphilosophy.org/token/expr-2/1> a powla:Terminal ;
#     rdfs:label "a"@la ;
#     lila:hasLemma <http://lila-erc.eu/data/id/lemma/87344> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/document> ;
#     powla:next <http://latinphilosophy.org/token/expr-2/2> .
#
# <http://latinphilosophy.org/token/expr-2/2> a powla:Terminal ;
#     rdfs:label "fortiori"@la ;
#     lila:hasLemma <http://lila-erc.eu/data/id/lemma/103690> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/document> ;
#     powla:prev <http://latinphilosophy.org/token/expr-2/1> .
#
# <http://latinphilosophy.org/token/expr-3/1> a powla:Terminal ;
#     rdfs:label "a"@la ;
#     lila:hasLemma <http://lila-erc.eu/data/id/lemma/87344> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/document> ;
#     powla:next <http://latinphilosophy.org/token/expr-3/2> .
#
# <http://latinphilosophy.org/token/expr-3/3> a powla:Terminal ;
#     rdfs:label "ad"@la ;
#     lila:hasLemma <http://lila-erc.eu/data/id/lemma/87344> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/document> ;
#     powla:next <http://latinphilosophy.org/token/expr-3/4> ;
#     powla:prev <http://latinphilosophy.org/token/expr-3/2> .
#
# <http://latinphilosophy.org/token/expr-3/6> a powla:Terminal ;
#     rdfs:label "consequentia"@la ;
#     lila:hasLemma <http://lila-erc.eu/data/id/lemma/97801> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/document> ;
#     powla:prev <http://latinphilosophy.org/token/expr-3/5> .
#
# <http://latinphilosophy.org/token/expr-4/1> a powla:Terminal ;
#     rdfs:label "a"@la ;
#     lila:hasLemma <http://lila-erc.eu/data/id/lemma/87344> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/document> ;
#     powla:next <http://latinphilosophy.org/token/expr-4/2> .
#
# <http://latinphilosophy.org/token/expr-4/2> a powla:Terminal ;
#     rdfs:label "posteriori"@la ;
#     lila:hasLemma <http://lila-erc.eu/data/id/lemma/120781> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/document> ;
#     powla:prev <http://latinphilosophy.org/token/expr-4/1> .
#
# <http://latinphilosophy.org/token/expr-5/1> a powla:Terminal ;
#     rdfs:label "a"@la ;
#     lila:hasLemma <http://lila-erc.eu/data/id/lemma/87344> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/document> ;
#     powla:next <http://latinphilosophy.org/token/expr-5/2> .
#
# <http://latinphilosophy.org/token/expr-5/2> a powla:Terminal ;
#     rdfs:label "priori"@la ;
#     lila:hasLemma <http://lila-erc.eu/data/id/lemma/119509> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/document> ;
#     powla:prev <http://latinphilosophy.org/token/expr-5/1> .
#
# <http://latinphilosophy.org/token/expr-6/1> a powla:Terminal ;
#     rdfs:label "ab"@la ;
#     lila:hasLemma <http://lila-erc.eu/data/id/lemma/87344> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/document> ;
#     powla:next <http://latinphilosophy.org/token/expr-6/2> .
#
# <http://latinphilosophy.org/token/expr-6/3> a powla:Terminal ;
#     rdfs:label "ad"@la ;
#     lila:hasLemma <http://lila-erc.eu/data/id/lemma/87344> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/document> ;
#     powla:next <http://latinphilosophy.org/token/expr-6/4> ;
#     powla:prev <http://latinphilosophy.org/token/expr-6/2> .
#
# <http://latinphilosophy.org/token/expr-6/6> a powla:Terminal ;
#     rdfs:label "consequentia"@la ;
#     lila:hasLemma <http://lila-erc.eu/data/id/lemma/97801> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/document> ;
#     powla:prev <http://latinphilosophy.org/token/expr-6/5> .
#
# <http://latinphilosophy.org/token/expr-7/1> a powla:Terminal ;
#     rdfs:label "ab"@la ;
#     lila:hasLemma <http://lila-erc.eu/data/id/lemma/87344> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/document> ;
#     powla:next <http://latinphilosophy.org/token/expr-7/2> .
#
# <http://latinphilosophy.org/token/expr-7/2> a powla:Terminal ;
#     rdfs:label "ovo"@la ;
#     lila:hasLemma <http://lila-erc.eu/data/id/lemma/115446> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/document> ;
#     powla:prev <http://latinphilosophy.org/token/expr-7/1> .
#
# <http://latinphilosophy.org/token/expr-8/1> a powla:Terminal ;
#     rdfs:label "actus"@la ;
#     lila:hasLemma <http://lila-erc.eu/data/id/lemma/91175> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/document> ;
#     powla:next <http://latinphilosophy.org/token/expr-8/2> .
#
# <http://latinphilosophy.org/token/expr-8/2> a powla:Terminal ;
#     rdfs:label "purus"@la ;
#     lila:hasLemma <http://lila-erc.eu/data/id/lemma/120570> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/document> ;
#     powla:prev <http://latinphilosophy.org/token/expr-8/1> .
#
# <http://latinphilosophy.org/token/expr-9/1> a powla:Terminal ;
#     rdfs:label "ad"@la ;
#     lila:hasLemma <http://lila-erc.eu/data/id/lemma/87344> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/document> ;
#     powla:next <http://latinphilosophy.org/token/expr-9/2> .
#
# <http://latinphilosophy.org/token/expr-9/2> a powla:Terminal ;
#     rdfs:label "hoc"@la ;
#     lila:hasLemma <http://lila-erc.eu/data/id/lemma/105455> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/document> ;
#     powla:prev <http://latinphilosophy.org/token/expr-9/1> .
#
# <http://latinphilosophy.org/feat/case=abl> a <https://universaldependencies.org/u/feat/Case#Abl> ;
#     rdfs:label "Case=Abl" .
#
# <http://latinphilosophy.org/token/expr-0/4> a powla:Terminal ;
#     rdfs:label "quid"@la ;
#     lila:hasLemma <http://lila-erc.eu/data/id/lemma/121354> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/document> ;
#     powla:next <http://latinphilosophy.org/token/expr-0/5> ;
#     powla:prev <http://latinphilosophy.org/token/expr-0/3> .
#
# <http://latinphilosophy.org/token/expr-1/7> a powla:Terminal ;
#     rdfs:label "quid"@la ;
#     lila:hasLemma <http://lila-erc.eu/data/id/lemma/121354> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/document> ;
#     powla:prev <http://latinphilosophy.org/token/expr-1/6> .
#
# <http://latinphilosophy.org/token/expr-3/4> a powla:Terminal ;
#     rdfs:label "esse"@la ;
#     lila:hasLemma <http://lila-erc.eu/data/id/lemma/50040> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/document> ;
#     powla:next <http://latinphilosophy.org/token/expr-3/5> ;
#     powla:prev <http://latinphilosophy.org/token/expr-3/3> .
#
# <http://latinphilosophy.org/token/expr-3/5> a powla:Terminal ;
#     rdfs:label "valet"@la ;
#     lila:hasLemma <http://lila-erc.eu/data/id/lemma/129509> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/document> ;
#     powla:next <http://latinphilosophy.org/token/expr-3/6> ;
#     powla:prev <http://latinphilosophy.org/token/expr-3/4> .
#
# <http://latinphilosophy.org/token/expr-6/2> a powla:Terminal ;
#     rdfs:label "esse"@la ;
#     lila:hasLemma <http://lila-erc.eu/data/id/lemma/50040> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/document> ;
#     powla:next <http://latinphilosophy.org/token/expr-6/3> ;
#     powla:prev <http://latinphilosophy.org/token/expr-6/1> .
#
# <http://latinphilosophy.org/token/expr-6/4> a powla:Terminal ;
#     rdfs:label "posse"@la ;
#     lila:hasLemma <http://lila-erc.eu/data/id/lemma/118569> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/document> ;
#     powla:next <http://latinphilosophy.org/token/expr-6/5> ;
#     powla:prev <http://latinphilosophy.org/token/expr-6/3> .
#
# <http://latinphilosophy.org/token/expr-0/2> a powla:Terminal ;
#     rdfs:label "dicto"@la ;
#     lila:hasLemma <http://lila-erc.eu/data/id/lemma/100416> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/document> ;
#     powla:next <http://latinphilosophy.org/token/expr-0/3> ;
#     powla:prev <http://latinphilosophy.org/token/expr-0/1> .
#
# <http://latinphilosophy.org/token/expr-0/6> a powla:Terminal ;
#     rdfs:label "dictum"@la ;
#     lila:hasLemma <http://lila-erc.eu/data/id/lemma/100416> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/document> ;
#     powla:next <http://latinphilosophy.org/token/expr-0/7> ;
#     powla:prev <http://latinphilosophy.org/token/expr-0/5> .
#
# <http://latinphilosophy.org/token/expr-1/2> a powla:Terminal ;
#     rdfs:label "dicto"@la ;
#     lila:hasLemma <http://lila-erc.eu/data/id/lemma/100416> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/document> ;
#     powla:next <http://latinphilosophy.org/token/expr-1/3> ;
#     powla:prev <http://latinphilosophy.org/token/expr-1/1> .
#
# <http://latinphilosophy.org/token/expr-1/5> a powla:Terminal ;
#     rdfs:label "dictum"@la ;
#     lila:hasLemma <http://lila-erc.eu/data/id/lemma/100416> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/document> ;
#     powla:next <http://latinphilosophy.org/token/expr-1/6> ;
#     powla:prev <http://latinphilosophy.org/token/expr-1/4> .
#
# <http://latinphilosophy.org/token/expr-3/2> a powla:Terminal ;
#     rdfs:label "necesse"@la ;
#     lila:hasLemma <http://lila-erc.eu/data/id/lemma/113513> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/document> ;
#     powla:next <http://latinphilosophy.org/token/expr-3/3> ;
#     powla:prev <http://latinphilosophy.org/token/expr-3/1> .
#
# <http://latinphilosophy.org/token/expr-6/5> a powla:Terminal ;
#     rdfs:label "valet"@la ;
#     lila:hasLemma <http://lila-erc.eu/data/id/lemma/129509> ;
#     powla:hasLayer <http://latinphilosophy.org/layer/document> ;
#     powla:next <http://latinphilosophy.org/token/expr-6/6> ;
#     powla:prev <http://latinphilosophy.org/token/expr-6/4> .
#
# <http://latinphilosophy.org/creator/leibniz> rdfs:label "Leibniz"@en ;
#     rdfs:seeAlso <https://www.wikidata.org/wiki/Q9047> ;
#     foaf:page <https://www.wikidata.org/wiki/Q9047> .
#
# <http://latinphilosophy.org/feat/gender=neut> a <https://universaldependencies.org/u/feat/Gender#Neut> ;
#     rdfs:label "Gender=Neut" .
#
# <http://latinphilosophy.org/pos/noun> rdfs:label "POS=NOUN" .
#
# <http://latinphilosophy.org/layer/expression> a powla:DocumentLayer ;
#     rdfs:label "Expression Layer" ;
#     powla:hasDocument lp:corpus .
#
# <http://latinphilosophy.org/lexicon/en> a lime:lexicon ;
#     rdfs:label "English lexicon" .
#
# <http://latinphilosophy.org/lexicon/la> a lime:lexicon ;
#     rdfs:label "Latin lexicon" .
#
# <http://latinphilosophy.org/layer/semantics> a powla:Layer ;
#     rdfs:label "Semantic Annotation Layer" .
#
# <http://latinphilosophy.org/creator/david-hume> rdfs:label "David Hume"@en ;
#     rdfs:seeAlso <https://www.wikidata.org/wiki/Q37160> ;
#     foaf:page <https://www.wikidata.org/wiki/Q37160> .
#
# <http://latinphilosophy.org/creator/thomas-aquinas> rdfs:label "Thomas Aquinas"@en ;
#     rdfs:seeAlso <https://www.wikidata.org/wiki/Q9438> ;
#     foaf:page <https://www.wikidata.org/wiki/Q9438> .
#
# <http://lila-erc.eu/data/id/lemma/87344> a lila:lemma ;
#     rdfs:label "ab",
#         "ad" ;
#     dc:title "ab",
#         "ad" .
#
# <http://latinphilosophy.org/creator/immanuel-kant> rdfs:label "Immanuel Kant"@en ;
#     rdfs:seeAlso <https://www.wikidata.org/wiki/Q9312> ;
#     foaf:page <https://www.wikidata.org/wiki/Q9312> .
#
# <http://latinphilosophy.org/feat/adptype=prep> a <https://universaldependencies.org/u/feat/Adptype#Prep> ;
#     rdfs:label "Adptype=Prep" .
#
# <http://latinphilosophy.org/pos/adp> rdfs:label "POS=ADP" .
#
# <http://latinphilosophy.org/creator/aristotle> rdfs:label "Aristotle"@en ;
#     rdfs:seeAlso <https://www.wikidata.org/wiki/Q84473023> ;
#     foaf:page <https://www.wikidata.org/wiki/Q84473023> .
#
# <http://latinphilosophy.org/feat/number=sing> a <https://universaldependencies.org/u/feat/Number#Sing> ;
#     rdfs:label "Number=Sing" .
#
# <http://latinphilosophy.org/layer/dependency> a powla:Layer ;
#     rdfs:label "Dependency Annotation Layer" .
#
# <http://latinphilosophy.org/layer/document> a powla:DocumentLayer ;
#     rdfs:label "Document Layer" ;
#     powla:hasDocument lp:corpus .
#
# <http://latinphilosophy.org/layer/ud> a powla:Layer ;
#     rdfs:label "UD Annotation Layer" .

# %%
g.serialize(format="turtle", destination="Latin-Philosophical-Expression.ttl")
# Out:
# <Graph identifier=Nd199e7b850f341a08c04a9612ca26fd0 (<class 'rdflib.graph.Graph'>)>

# %%
 len(g)
# Out:
# 19561
